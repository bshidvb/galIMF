# %%
from scipy.integrate import quad
import glob
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

def load_data_with_names(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    data_dict = {}
    for i in range(len(lines)):
        line = lines[i].strip()
        if line.startswith("#"):
            row_name = line[1:].strip()
            if i + 1 < len(lines):
                data = list(map(float, lines[i + 1].strip().split()))
                data_dict[row_name] = data
    return data_dict

def prepare_data(file_paths):
    for path in file_paths:
        data = load_data_with_names(path)
        age_list = data['age_list']
        sfh = data['SFR_list']
        # timestep = data['time step list:']
    #     logNO_rec, logOH_rec = recalculate(logNO, logOH)
    #     smooth_logOH, smooth_logNO = fit(logOH_rec, logNO_rec)
    # return smooth_logOH, smooth_logNO
    return age_list, sfh

# %%
path = "./simulation_results_from_galaxy_evol/13.6/imfKroupaSTF0.04alpha1.15log_SFR<module 'IMFs.Kroupa_IMF' from '/Users/adriana_work/Desktop/galIMF/IMFs/Kroupa_IMF.py'>SFEN2.0SFE30Z_0-4.15/plots/SFH.txt"
age_list, sfh = prepare_data([path])

plt.plot(age_list, sfh, label='SFH', lw=0.8)
plt.xlabel('Time (Gyr)')
plt.ylabel('Star Formation Rate (M☉/yr)')
plt.title('Star Formation History')
plt.legend()

plt.show()

# %%
path = "./simulation_results_from_galaxy_evol/20250729/imfKroupaSTF0.04alpha2.35log_SFR<module 'IMFs.Kroupa_IMF' from '/Users/adriana_work/Desktop/galIMF/IMFs/Kroupa_IMF.py'>SFEN1.0SFE60Z_0-4.15/plots/SFH.txt"
age_list, sfh = prepare_data([path])

plt.plot(age_list, sfh, label='SFH', lw=0.8)
plt.xlim(0, 0.4)
plt.ylim(-2, 2)
plt.xlabel('Time (Gyr)')
plt.ylabel('Star Formation Rate (M☉/yr)')
plt.title('Star Formation History')
plt.legend()

plt.show()

# %%
path = "./simulation_results_from_galaxy_evol/20250813/imfKroupaSTF-4.15alpha2.1log_SFR<module 'IMFs.Kroupa_IMF' from '/Users/adriana_work/Desktop/galIMF/IMFs/Kroupa_IMF.py'>SFEN1.3SFE0.012Z_015infall0.008/plots/SFH.txt"
age_list, sfh = prepare_data([path])

plt.plot(age_list, sfh, label='SFH', lw=0.8)
plt.xlim(0, 0.4)
plt.ylim(-2, 2)
plt.xlabel('Time (Gyr)')
plt.ylabel('Star Formation Rate (M☉/yr)')
plt.title('Star Formation History')
plt.legend()
plt.savefig('./figs/galevo/SFH_alpha2-1.png', dpi=300, bbox_inches='tight')
plt.show()
