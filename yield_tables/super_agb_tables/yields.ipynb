# %%
import re

def process_file(input_file, output_file):
    with open(input_file, 'r') as file:
        lines = file.readlines()

    processed_lines = []
    Z = None  # Initialize Z value
    for line in lines:
        # Match lines containing Z value
        z_match = re.search(r'Z=(\d+\.\d+)', line)
        if z_match:
            Z = float(z_match.group(1))
            processed_lines.append(line)  # Keep the Z line unchanged
            continue
        
        # Process rows with data
        if Z is not None and re.search(r'&\w+', line):
            columns = line.split('&')
            if len(columns) > 4:  # Ensure it has the X_i,solar column
                try:
                    X_i_solar = float(columns[4].strip())
                    X_i_0 = X_i_solar * Z / 0.0134
                    columns.append(f'{X_i_0:.6E}')
                    processed_lines.append('&'.join(columns) + '\n')
                except ValueError:
                    processed_lines.append(line)
                print(columns[4])  # Debug print for X_i,solar
            else:
                processed_lines.append(line)
        else:
            processed_lines.append(line)

    with open(output_file, 'w') as file:
        file.writelines(processed_lines)

# Input and output file paths
input_file = 'super_agb_doherty13_original_file.txt'
output_file = 'super_agb_doherty13_processed_file.txt'

process_file(input_file, output_file)
# Out:
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06
#
# X_i,solar
# 7.057E-01
#
# 3.461E-05
#
# 2.769E-01
#
# 1.025E-08
#
# 3.011E-03
#
# 3.411E-05
#
# 8.482E-04
#
# 2.059E-06
#
# 7.377E-03
#
# 2.739E-06
#
# 1.565E-05
#
# 6.688E-07
#
# 2.261E-03
#
# 5.693E-06
#
# 1.772E-04
#
# 3.692E-05
#
# 5.398E-04
#
# 7.151E-05
#
# 8.158E-05
#
# 0.0
#
# 6.132E-05
#
# 7.167E-04
#
# 3.768E-05
#
# 2.573E-05
#
# 7.109E-06
#
# 3.692E-04
#
# 2.996E-06
#
# 1.727E-05
#
# 0.0
#
# 7.643E-05
#
# 0.0
#
# 1.245E-03
#
# 2.927E-05
#
# 3.960E-06
#
# 0.0
#
# 3.701E-06
#
# 5.328E-05
#
# 2.131E-05
#
# 9.396E-07
#
# 3.046E-06

# %%
import re

# File paths
input_file = "super_agb_doherty13_x_i,0.txt"
output_file = "super_agb_doherty13_total_yields.txt"

# Regular expression to match rows starting with '&'
row_pattern = re.compile(r"^&")

# Read the input file
with open(input_file, 'r') as file:
    lines = file.readlines()

# Process the file
updated_lines = []
for line in lines:
    if row_pattern.match(line):
        # Split the line into columns
        columns = line.split()
        # Debug: Print the raw columns for inspection
        print(f"Raw columns: {columns}")
        # Ensure the row has enough columns and valid numeric data
        if len(columns) < 5:
            print(f"Skipping line due to insufficient columns: {line.strip()}")
            continue
        try:
            # Extract relevant values, handling the '&' symbol
            p_i = float(columns[1].lstrip('&'))  # Net Yield
            M_ej = float(columns[2].lstrip('&'))  # MassExp
            X_i_0 = float(columns[4].lstrip('&'))  # X_i,0 (last column)
            # Calculate Total yield
            total_yield = p_i + M_ej * X_i_0

            # Update the Total yield column (8th column, index 7)
            columns[4] = f"{total_yield:.6e}"
        except ValueError as e:
            print(f"Skipping line due to ValueError: {line.strip()} - {e}")
            continue

        # Reconstruct the line
        line = " ".join(columns) + "\n"
        print(f"Processed line: {line.strip()}")  # Debug: Print the processed line

    # Append the processed or unprocessed line
    updated_lines.append(line)

# Write the updated lines back to the file
with open(output_file, 'w') as file:
    file.writelines(updated_lines)
# Out:
# Raw columns: ['&Isotopes', '&NetYield', '&MassExp', '&X_i,solar', '&X_i,0', '&Yields']
# Skipping line due to ValueError: &Isotopes &NetYield &MassExp &X_i,solar &X_i,0 &Yields - could not convert string to float: 'NetYield'
# Raw columns: ['&H', '&-4.832E-01', '&3.770E+00', '&7.057E-01', '&1.053284E+00']
# Processed line: &H &-4.832E-01 &3.770E+00 &7.057E-01 3.487681e+00
# Raw columns: ['&He-3', '&1.589E-05', '&1.589E-05', '&3.461E-05', '&5.165672E-05']
# Processed line: &He-3 &1.589E-05 &1.589E-05 &3.461E-05 1.589082e-05
# Raw columns: ['&He-4', '&4.687E-01', '&2.128E+00', '&2.769E-01', '&4.132836E-01']
# Processed line: &He-4 &4.687E-01 &2.128E+00 &2.769E-01 1.348168e+00
# Raw columns: ['&Li-7', '&-6.037E-09', '&5.857E-08', '&1.025E-08', '&1.529851E-08']
# Processed line: &Li-7 &-6.037E-09 &5.857E-08 &1.025E-08 -6.036999e-09
# Raw columns: ['&C-12', '&-1.386E-02', '&6.763E-03', '&3.011E-03', '&4.494030E-03']
# Processed line: &C-12 &-1.386E-02 &6.763E-03 &3.011E-03 -1.382961e-02
# Raw columns: ['&C-13', '&5.506E-04', '&7.983E-04', '&3.411E-05', '&5.091045E-05']
# Processed line: &C-13 &5.506E-04 &7.983E-04 &3.411E-05 5.506406e-04
# Raw columns: ['&N-14', '&3.668E-02', '&4.301E-02', '&8.482E-04', '&1.265970E-03']
# Processed line: &N-14 &3.668E-02 &4.301E-02 &8.482E-04 3.673445e-02
# Raw columns: ['&N-15', '&-2.382E-05', '&1.195E-06', '&2.059E-06', '&3.073134E-06']
# Processed line: &N-15 &-2.382E-05 &1.195E-06 &2.059E-06 -2.382000e-05
# Raw columns: ['&O-16', '&-9.816E-03', '&4.764E-02', '&7.377E-03', '&1.101045E-02']
# Processed line: &O-16 &-9.816E-03 &4.764E-02 &7.377E-03 -9.291462e-03
# Raw columns: ['&O-17', '&1.011E-04', '&1.245E-04', '&2.739E-06', '&4.088060E-06']
# Processed line: &O-17 &1.011E-04 &1.245E-04 &2.739E-06 1.011005e-04
# Raw columns: ['&O-18', '&-1.278E-04', '&2.485E-06', '&1.565E-05', '&2.335821E-05']
# Processed line: &O-18 &-1.278E-04 &2.485E-06 &1.565E-05 -1.277999e-04
# Raw columns: ['&F-19', '&-1.336E-06', '&2.033E-06', '&6.688E-07', '&9.982090E-07']
# Processed line: &F-19 &-1.336E-06 &2.033E-06 &6.688E-07 -1.335998e-06
# Raw columns: ['&Ne-20', '&-2.514E-05', '&1.089E-02', '&2.261E-03', '&3.374627E-03']
# Processed line: &Ne-20 &-2.514E-05 &1.089E-02 &2.261E-03 1.160969e-05
# Raw columns: ['&Ne-21', '&-2.559E-05', '&2.269E-06', '&5.693E-06', '&8.497015E-06']
# Processed line: &Ne-21 &-2.559E-05 &2.269E-06 &5.693E-06 -2.558998e-05
# Raw columns: ['&Ne-22', '&5.736E-04', '&1.450E-03', '&1.772E-04', '&2.644776E-04']
# Processed line: &Ne-22 &5.736E-04 &1.450E-03 &1.772E-04 5.739835e-04
# Raw columns: ['&Na-23', '&1.995E-04', '&4.395E-04', '&3.692E-05', '&5.510448E-05']
# Processed line: &Na-23 &1.995E-04 &4.395E-04 &3.692E-05 1.995242e-04
# Raw columns: ['&Mg-24', '&-4.026E-05', '&3.479E-03', '&5.398E-04', '&8.056716E-04']
# Processed line: &Mg-24 &-4.026E-05 &3.479E-03 &5.398E-04 -3.745707e-05
# Raw columns: ['&Mg-25', '&5.454E-05', '&5.186E-04', '&7.151E-05', '&1.067313E-04']
# Processed line: &Mg-25 &5.454E-05 &5.186E-04 &7.151E-05 5.459535e-05
# Raw columns: ['&Mg-26', '&2.058E-04', '&7.372E-04', '&8.158E-05', '&1.217612E-04']
# Processed line: &Mg-26 &2.058E-04 &7.372E-04 &8.158E-05 2.058898e-04
# Raw columns: ['&Al-26', '&3.064E-06', '&3.064E-06', '&0.0', '&0.000000E+00']
# Processed line: &Al-26 &3.064E-06 &3.064E-06 &0.0 3.064000e-06
# Raw columns: ['&Al-27', '&1.799E-05', '&4.071E-04', '&6.132E-05', '&9.152239E-05']
# Processed line: &Al-27 &1.799E-05 &4.071E-04 &6.132E-05 1.802726e-05
# Raw columns: ['&Si-28', '&1.338E-05', '&4.488E-03', '&7.167E-04', '&1.069701E-03']
# Processed line: &Si-28 &1.338E-05 &4.488E-03 &7.167E-04 1.818082e-05
# Raw columns: ['&Si-29', '&2.862E-06', '&2.375E-04', '&3.768E-05', '&5.623881E-05']
# Processed line: &Si-29 &2.862E-06 &2.375E-04 &3.768E-05 2.875357e-06
# Raw columns: ['&Si-30', '&5.693E-06', '&1.668E-04', '&2.573E-05', '&3.840299E-05']
# Processed line: &Si-30 &5.693E-06 &1.668E-04 &2.573E-05 5.699406e-06
# Raw columns: ['&P-31', '&8.879E-07', '&4.354E-05', '&7.109E-06', '&1.061045E-05']
# Processed line: &P-31 &8.879E-07 &4.354E-05 &7.109E-06 8.883620e-07
# Raw columns: ['&S-32', '&-4.810E-06', '&3.169E-03', '&3.692E-04', '&5.510448E-04']
# Processed line: &S-32 &-4.810E-06 &3.169E-03 &3.692E-04 -3.063739e-06
# Raw columns: ['&S-33', '&1.970E-07', '&2.604E-05', '&2.996E-06', '&4.471642E-06']
# Processed line: &S-33 &1.970E-07 &2.604E-05 &2.996E-06 1.971164e-07
# Raw columns: ['&S-34', '&-4.791E-06', '&1.287E-03', '&1.727E-05', '&2.577612E-05']
# Processed line: &S-34 &-4.791E-06 &1.287E-03 &1.727E-05 -4.757826e-06
# Raw columns: ['&S-35', '&5.194E-06', '&5.194E-06', '&0.0', '&0.000000E+00']
# Processed line: &S-35 &5.194E-06 &5.194E-06 &0.0 5.194000e-06
# Raw columns: ['&Fe-54', '&-3.794E-06', '&4.799E-04', '&7.643E-05', '&1.140746E-04']
# Processed line: &Fe-54 &-3.794E-06 &4.799E-04 &7.643E-05 -3.739256e-06
# Raw columns: ['&Fe-55', '&1.175E-06', '&1.175E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-55 &1.175E-06 &1.175E-06 &0.0 1.175000e-06
# Raw columns: ['&Fe-56', '&-3.125E-05', '&7.897E-03', '&1.245E-03', '&1.858209E-03']
# Processed line: &Fe-56 &-3.125E-05 &7.897E-03 &1.245E-03 -1.657572e-05
# Raw columns: ['&Fe-57', '&6.703E-06', '&2.003E-04', '&2.927E-05', '&4.368657E-05']
# Processed line: &Fe-57 &6.703E-06 &2.003E-04 &2.927E-05 6.711750e-06
# Raw columns: ['&Fe-58', '&1.582E-05', '&4.089E-05', '&3.960E-06', '&5.910448E-06']
# Processed line: &Fe-58 &1.582E-05 &4.089E-05 &3.960E-06 1.582024e-05
# Raw columns: ['&Fe-60', '&2.817E-06', '&2.817E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-60 &2.817E-06 &2.817E-06 &0.0 2.817000e-06
# Raw columns: ['&Co-59', '&4.686E-06', '&2.865E-05', '&3.701E-06', '&5.523881E-06']
# Processed line: &Co-59 &4.686E-06 &2.865E-05 &3.701E-06 4.686158e-06
# Raw columns: ['&Ni-58', '&-2.402E-06', '&3.414E-04', '&5.328E-05', '&7.952239E-05']
# Processed line: &Ni-58 &-2.402E-06 &3.414E-04 &5.328E-05 -2.374851e-06
# Raw columns: ['&Ni-60', '&1.029E-06', '&1.370E-04', '&2.131E-05', '&3.180597E-05']
# Processed line: &Ni-60 &1.029E-06 &1.370E-04 &2.131E-05 1.033357e-06
# Raw columns: ['&Ni-61', '&2.578E-05', '&3.176E-05', '&9.396E-07', '&1.402388E-06']
# Processed line: &Ni-61 &2.578E-05 &3.176E-05 &9.396E-07 2.578004e-05
# Raw columns: ['&Ni-62', '&-1.920E-05', '&1.292E-07', '&3.046E-06', '&4.546269E-06']
# Processed line: &Ni-62 &-1.920E-05 &1.292E-07 &3.046E-06 -1.920000e-05
# Raw columns: ['&Isotopes', '&NetYield', '&MassExp', '&X_i,solar', '&X_i,0', '&Yields']
# Skipping line due to ValueError: &Isotopes &NetYield &MassExp &X_i,solar &X_i,0 &Yields - could not convert string to float: 'NetYield'
# Raw columns: ['&H', '&-5.584E-01', '&4.017E+00', '&7.057E-01', '&1.053284E+00']
# Processed line: &H &-5.584E-01 &4.017E+00 &7.057E-01 3.672642e+00
# Raw columns: ['&He-3', '&1.828E-05', '&1.828E-05', '&3.461E-05', '&5.165672E-05']
# Processed line: &He-3 &1.828E-05 &1.828E-05 &3.461E-05 1.828094e-05
# Raw columns: ['&He-4', '&5.446E-01', '&2.329E+00', '&2.769E-01', '&4.132836E-01']
# Processed line: &He-4 &5.446E-01 &2.329E+00 &2.769E-01 1.507138e+00
# Raw columns: ['&Li-7', '&1.143E-08', '&8.094E-08', '&1.025E-08', '&1.529851E-08']
# Processed line: &Li-7 &1.143E-08 &8.094E-08 &1.025E-08 1.143000e-08
# Raw columns: ['&C-12', '&-1.481E-02', '&7.379E-03', '&3.011E-03', '&4.494030E-03']
# Processed line: &C-12 &-1.481E-02 &7.379E-03 &3.011E-03 -1.477684e-02
# Raw columns: ['&C-13', '&6.342E-04', '&9.007E-04', '&3.411E-05', '&5.091045E-05']
# Processed line: &C-13 &6.342E-04 &9.007E-04 &3.411E-05 6.342459e-04
# Raw columns: ['&N-14', '&3.852E-02', '&4.533E-02', '&8.482E-04', '&1.265970E-03']
# Processed line: &N-14 &3.852E-02 &4.533E-02 &8.482E-04 3.857739e-02
# Raw columns: ['&N-15', '&-2.556E-05', '&1.352E-06', '&2.059E-06', '&3.073134E-06']
# Processed line: &N-15 &-2.556E-05 &1.352E-06 &2.059E-06 -2.556000e-05
# Raw columns: ['&O-16', '&-1.147E-02', '&5.034E-02', '&7.377E-03', '&1.101045E-02']
# Processed line: &O-16 &-1.147E-02 &5.034E-02 &7.377E-03 -1.091573e-02
# Raw columns: ['&O-17', '&1.259E-04', '&1.511E-04', '&2.739E-06', '&4.088060E-06']
# Processed line: &O-17 &1.259E-04 &1.511E-04 &2.739E-06 1.259006e-04
# Raw columns: ['&O-18', '&-1.376E-04', '&2.614E-06', '&1.565E-05', '&2.335821E-05']
# Processed line: &O-18 &-1.376E-04 &2.614E-06 &1.565E-05 -1.375999e-04
# Raw columns: ['&F-19', '&-1.767E-06', '&1.857E-06', '&6.688E-07', '&9.982090E-07']
# Processed line: &F-19 &-1.767E-06 &1.857E-06 &6.688E-07 -1.766998e-06
# Raw columns: ['&Ne-20', '&-2.753E-05', '&1.172E-02', '&2.261E-03', '&3.374627E-03']
# Processed line: &Ne-20 &-2.753E-05 &1.172E-02 &2.261E-03 1.202063e-05
# Raw columns: ['&Ne-21', '&-2.698E-05', '&2.986E-06', '&5.693E-06', '&8.497015E-06']
# Processed line: &Ne-21 &-2.698E-05 &2.986E-06 &5.693E-06 -2.697997e-05
# Raw columns: ['&Ne-22', '&4.056E-04', '&1.349E-03', '&1.772E-04', '&2.644776E-04']
# Processed line: &Ne-22 &4.056E-04 &1.349E-03 &1.772E-04 4.059568e-04
# Raw columns: ['&Na-23', '&2.291E-04', '&4.873E-04', '&3.692E-05', '&5.510448E-05']
# Processed line: &Na-23 &2.291E-04 &4.873E-04 &3.692E-05 2.291269e-04
# Raw columns: ['&Mg-24', '&-6.522E-05', '&3.721E-03', '&5.398E-04', '&8.056716E-04']
# Processed line: &Mg-24 &-6.522E-05 &3.721E-03 &5.398E-04 -6.222210e-05
# Raw columns: ['&Mg-25', '&9.222E-05', '&5.914E-04', '&7.151E-05', '&1.067313E-04']
# Processed line: &Mg-25 &9.222E-05 &5.914E-04 &7.151E-05 9.228312e-05
# Raw columns: ['&Mg-26', '&2.652E-04', '&8.368E-04', '&8.158E-05', '&1.217612E-04']
# Processed line: &Mg-26 &2.652E-04 &8.368E-04 &8.158E-05 2.653019e-04
# Raw columns: ['&Al-26', '&4.072E-06', '&4.072E-06', '&0.0', '&0.000000E+00']
# Processed line: &Al-26 &4.072E-06 &4.072E-06 &0.0 4.072000e-06
# Raw columns: ['&Al-27', '&1.370E-05', '&4.323E-04', '&6.132E-05', '&9.152239E-05']
# Processed line: &Al-27 &1.370E-05 &4.323E-04 &6.132E-05 1.373957e-05
# Raw columns: ['&Si-28', '&1.673E-05', '&4.830E-03', '&7.167E-04', '&1.069701E-03']
# Processed line: &Si-28 &1.673E-05 &4.830E-03 &7.167E-04 2.189666e-05
# Raw columns: ['&Si-29', '&3.670E-06', '&2.560E-04', '&3.768E-05', '&5.623881E-05']
# Processed line: &Si-29 &3.670E-06 &2.560E-04 &3.768E-05 3.684397e-06
# Raw columns: ['&Si-30', '&7.028E-06', '&1.803E-04', '&2.573E-05', '&3.840299E-05']
# Processed line: &Si-30 &7.028E-06 &1.803E-04 &2.573E-05 7.034924e-06
# Raw columns: ['&P-31', '&1.222E-06', '&4.711E-05', '&7.109E-06', '&1.061045E-05']
# Processed line: &P-31 &1.222E-06 &4.711E-05 &7.109E-06 1.222500e-06
# Raw columns: ['&S-32', '&-5.451E-06', '&3.409E-03', '&3.692E-04', '&5.510448E-04']
# Processed line: &S-32 &-5.451E-06 &3.409E-03 &3.692E-04 -3.572488e-06
# Raw columns: ['&S-33', '&1.706E-07', '&2.797E-05', '&2.996E-06', '&4.471642E-06']
# Processed line: &S-33 &1.706E-07 &2.797E-05 &2.996E-06 1.707251e-07
# Raw columns: ['&S-34', '&-5.226E-06', '&1.385E-03', '&1.727E-05', '&2.577612E-05']
# Processed line: &S-34 &-5.226E-06 &1.385E-03 &1.727E-05 -5.190300e-06
# Raw columns: ['&S-35', '&5.681E-06', '&5.681E-06', '&0.0', '&0.000000E+00']
# Processed line: &S-35 &5.681E-06 &5.681E-06 &0.0 5.681000e-06
# Raw columns: ['&Fe-54', '&-3.972E-06', '&5.164E-04', '&7.643E-05', '&1.140746E-04']
# Processed line: &Fe-54 &-3.972E-06 &5.164E-04 &7.643E-05 -3.913092e-06
# Raw columns: ['&Fe-55', '&1.354E-06', '&1.354E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-55 &1.354E-06 &1.354E-06 &0.0 1.354000e-06
# Raw columns: ['&Fe-56', '&-3.367E-05', '&8.496E-03', '&1.245E-03', '&1.858209E-03']
# Processed line: &Fe-56 &-3.367E-05 &8.496E-03 &1.245E-03 -1.788266e-05
# Raw columns: ['&Fe-57', '&5.714E-06', '&2.140E-04', '&2.927E-05', '&4.368657E-05']
# Processed line: &Fe-57 &5.714E-06 &2.140E-04 &2.927E-05 5.723349e-06
# Raw columns: ['&Fe-58', '&1.547E-05', '&4.244E-05', '&3.960E-06', '&5.910448E-06']
# Processed line: &Fe-58 &1.547E-05 &4.244E-05 &3.960E-06 1.547025e-05
# Raw columns: ['&Fe-60', '&4.423E-06', '&4.423E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-60 &4.423E-06 &4.423E-06 &0.0 4.423000e-06
# Raw columns: ['&Co-59', '&5.249E-06', '&3.103E-05', '&3.701E-06', '&5.523881E-06']
# Processed line: &Co-59 &5.249E-06 &3.103E-05 &3.701E-06 5.249171e-06
# Raw columns: ['&Ni-58', '&-2.407E-06', '&3.674E-04', '&5.328E-05', '&7.952239E-05']
# Processed line: &Ni-58 &-2.407E-06 &3.674E-04 &5.328E-05 -2.377783e-06
# Raw columns: ['&Ni-60', '&1.049E-06', '&1.473E-04', '&2.131E-05', '&3.180597E-05']
# Processed line: &Ni-60 &1.049E-06 &1.473E-04 &2.131E-05 1.053685e-06
# Raw columns: ['&Ni-61', '&2.908E-05', '&3.551E-05', '&9.396E-07', '&1.402388E-06']
# Processed line: &Ni-61 &2.908E-05 &3.551E-05 &9.396E-07 2.908005e-05
# Raw columns: ['&Ni-62', '&-2.065E-05', '&1.357E-07', '&3.046E-06', '&4.546269E-06']
# Processed line: &Ni-62 &-2.065E-05 &1.357E-07 &3.046E-06 -2.065000e-05
# Raw columns: ['&Isotopes', '&NetYield', '&MassExp', '&X_i,solar', '&X_i,0', '&Yields']
# Skipping line due to ValueError: &Isotopes &NetYield &MassExp &X_i,solar &X_i,0 &Yields - could not convert string to float: 'NetYield'
# Raw columns: ['&H', '&-6.279E-01', '&4.256E+00', '&7.057E-01', '&1.053284E+00']
# Processed line: &H &-6.279E-01 &4.256E+00 &7.057E-01 3.854877e+00
# Raw columns: ['&He-3', '&1.879E-05', '&1.879E-05', '&3.461E-05', '&5.165672E-05']
# Processed line: &He-3 &1.879E-05 &1.879E-05 &3.461E-05 1.879097e-05
# Raw columns: ['&He-4', '&6.127E-01', '&2.518E+00', '&2.769E-01', '&4.132836E-01']
# Processed line: &He-4 &6.127E-01 &2.518E+00 &2.769E-01 1.653348e+00
# Raw columns: ['&Li-7', '&3.805E-08', '&1.122E-07', '&1.025E-08', '&1.529851E-08']
# Processed line: &Li-7 &3.805E-08 &1.122E-07 &1.025E-08 3.805000e-08
# Raw columns: ['&C-12', '&-1.621E-02', '&7.470E-03', '&3.011E-03', '&4.494030E-03']
# Processed line: &C-12 &-1.621E-02 &7.470E-03 &3.011E-03 -1.617643e-02
# Raw columns: ['&C-13', '&7.861E-04', '&1.071E-03', '&3.411E-05', '&5.091045E-05']
# Processed line: &C-13 &7.861E-04 &1.071E-03 &3.411E-05 7.861545e-04
# Raw columns: ['&N-14', '&4.258E-02', '&4.985E-02', '&8.482E-04', '&1.265970E-03']
# Processed line: &N-14 &4.258E-02 &4.985E-02 &8.482E-04 4.264311e-02
# Raw columns: ['&N-15', '&-2.695E-05', '&1.778E-06', '&2.059E-06', '&3.073134E-06']
# Processed line: &N-15 &-2.695E-05 &1.778E-06 &2.059E-06 -2.694999e-05
# Raw columns: ['&O-16', '&-1.327E-02', '&5.270E-02', '&7.377E-03', '&1.101045E-02']
# Processed line: &O-16 &-1.327E-02 &5.270E-02 &7.377E-03 -1.268975e-02
# Raw columns: ['&O-17', '&1.730E-04', '&1.999E-04', '&2.739E-06', '&4.088060E-06']
# Processed line: &O-17 &1.730E-04 &1.999E-04 &2.739E-06 1.730008e-04
# Raw columns: ['&O-18', '&-1.467E-04', '&2.900E-06', '&1.565E-05', '&2.335821E-05']
# Processed line: &O-18 &-1.467E-04 &2.900E-06 &1.565E-05 -1.466999e-04
# Raw columns: ['&F-19', '&-2.461E-06', '&1.408E-06', '&6.688E-07', '&9.982090E-07']
# Processed line: &F-19 &-2.461E-06 &1.408E-06 &6.688E-07 -2.460999e-06
# Raw columns: ['&Ne-20', '&-2.084E-05', '&1.252E-02', '&2.261E-03', '&3.374627E-03']
# Processed line: &Ne-20 &-2.084E-05 &1.252E-02 &2.261E-03 2.141033e-05
# Raw columns: ['&Ne-21', '&-2.826E-05', '&3.734E-06', '&5.693E-06', '&8.497015E-06']
# Processed line: &Ne-21 &-2.826E-05 &3.734E-06 &5.693E-06 -2.825997e-05
# Raw columns: ['&Ne-22', '&5.392E-04', '&1.546E-03', '&1.772E-04', '&2.644776E-04']
# Processed line: &Ne-22 &5.392E-04 &1.546E-03 &1.772E-04 5.396089e-04
# Raw columns: ['&Na-23', '&2.479E-04', '&5.236E-04', '&3.692E-05', '&5.510448E-05']
# Processed line: &Na-23 &2.479E-04 &5.236E-04 &3.692E-05 2.479289e-04
# Raw columns: ['&Mg-24', '&-2.202E-04', '&3.821E-03', '&5.398E-04', '&8.056716E-04']
# Processed line: &Mg-24 &-2.202E-04 &3.821E-03 &5.398E-04 -2.171215e-04
# Raw columns: ['&Mg-25', '&2.988E-04', '&8.317E-04', '&7.151E-05', '&1.067313E-04']
# Processed line: &Mg-25 &2.988E-04 &8.317E-04 &7.151E-05 2.988888e-04
# Raw columns: ['&Mg-26', '&4.092E-04', '&1.019E-03', '&8.158E-05', '&1.217612E-04']
# Processed line: &Mg-26 &4.092E-04 &1.019E-03 &8.158E-05 4.093241e-04
# Raw columns: ['&Al-26', '&6.165E-06', '&6.165E-06', '&0.0', '&0.000000E+00']
# Processed line: &Al-26 &6.165E-06 &6.165E-06 &0.0 6.165000e-06
# Raw columns: ['&Al-27', '&1.041E-05', '&4.572E-04', '&6.132E-05', '&9.152239E-05']
# Processed line: &Al-27 &1.041E-05 &4.572E-04 &6.132E-05 1.045184e-05
# Raw columns: ['&Si-28', '&2.190E-05', '&5.160E-03', '&7.167E-04', '&1.069701E-03']
# Processed line: &Si-28 &2.190E-05 &5.160E-03 &7.167E-04 2.741966e-05
# Raw columns: ['&Si-29', '&5.766E-06', '&2.752E-04', '&3.768E-05', '&5.623881E-05']
# Processed line: &Si-29 &5.766E-06 &2.752E-04 &3.768E-05 5.781477e-06
# Raw columns: ['&Si-30', '&1.097E-05', '&1.960E-04', '&2.573E-05', '&3.840299E-05']
# Processed line: &Si-30 &1.097E-05 &1.960E-04 &2.573E-05 1.097753e-05
# Raw columns: ['&P-31', '&2.115E-06', '&5.110E-05', '&7.109E-06', '&1.061045E-05']
# Processed line: &P-31 &2.115E-06 &5.110E-05 &7.109E-06 2.115542e-06
# Raw columns: ['&S-32', '&-7.511E-06', '&3.637E-03', '&3.692E-04', '&5.510448E-04']
# Processed line: &S-32 &-7.511E-06 &3.637E-03 &3.692E-04 -5.506850e-06
# Raw columns: ['&S-33', '&1.528E-07', '&2.983E-05', '&2.996E-06', '&4.471642E-06']
# Processed line: &S-33 &1.528E-07 &2.983E-05 &2.996E-06 1.529334e-07
# Raw columns: ['&S-34', '&-6.459E-06', '&1.477E-03', '&1.727E-05', '&2.577612E-05']
# Processed line: &S-34 &-6.459E-06 &1.477E-03 &1.727E-05 -6.420929e-06
# Raw columns: ['&S-35', '&7.077E-06', '&7.077E-06', '&0.0', '&0.000000E+00']
# Processed line: &S-35 &7.077E-06 &7.077E-06 &0.0 7.077000e-06
# Raw columns: ['&Fe-54', '&-4.478E-06', '&5.510E-04', '&7.643E-05', '&1.140746E-04']
# Processed line: &Fe-54 &-4.478E-06 &5.510E-04 &7.643E-05 -4.415145e-06
# Raw columns: ['&Fe-55', '&1.564E-06', '&1.564E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-55 &1.564E-06 &1.564E-06 &0.0 1.564000e-06
# Raw columns: ['&Fe-56', '&-4.135E-05', '&9.063E-03', '&1.245E-03', '&1.858209E-03']
# Processed line: &Fe-56 &-4.135E-05 &9.063E-03 &1.245E-03 -2.450905e-05
# Raw columns: ['&Fe-57', '&4.519E-06', '&2.269E-04', '&2.927E-05', '&4.368657E-05']
# Processed line: &Fe-57 &4.519E-06 &2.269E-04 &2.927E-05 4.528912e-06
# Raw columns: ['&Fe-58', '&1.528E-05', '&4.407E-05', '&3.960E-06', '&5.910448E-06']
# Processed line: &Fe-58 &1.528E-05 &4.407E-05 &3.960E-06 1.528026e-05
# Raw columns: ['&Fe-60', '&9.088E-06', '&9.088E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-60 &9.088E-06 &9.088E-06 &0.0 9.088000e-06
# Raw columns: ['&Co-59', '&6.392E-06', '&3.391E-05', '&3.701E-06', '&5.523881E-06']
# Processed line: &Co-59 &6.392E-06 &3.391E-05 &3.701E-06 6.392187e-06
# Raw columns: ['&Ni-58', '&-2.619E-06', '&3.922E-04', '&5.328E-05', '&7.952239E-05']
# Processed line: &Ni-58 &-2.619E-06 &3.922E-04 &5.328E-05 -2.587811e-06
# Raw columns: ['&Ni-60', '&1.173E-06', '&1.573E-04', '&2.131E-05', '&3.180597E-05']
# Processed line: &Ni-60 &1.173E-06 &1.573E-04 &2.131E-05 1.178003e-06
# Raw columns: ['&Ni-61', '&3.482E-05', '&4.169E-05', '&9.396E-07', '&1.402388E-06']
# Processed line: &Ni-61 &3.482E-05 &4.169E-05 &9.396E-07 3.482006e-05
# Raw columns: ['&Ni-62', '&-2.205E-05', '&1.437E-07', '&3.046E-06', '&4.546269E-06']
# Processed line: &Ni-62 &-2.205E-05 &1.437E-07 &3.046E-06 -2.205000e-05
# Raw columns: ['&Isotopes', '&NetYield', '&MassExp', '&X_i,solar', '&X_i,0', '&Yields']
# Skipping line due to ValueError: &Isotopes &NetYield &MassExp &X_i,solar &X_i,0 &Yields - could not convert string to float: 'NetYield'
# Raw columns: ['&H', '&-6.849E-01', '&4.494E+00', '&7.057E-01', '&1.053284E+00']
# Processed line: &H &-6.849E-01 &4.494E+00 &7.057E-01 4.048558e+00
# Raw columns: ['&He-3', '&2.176E-05', '&2.176E-05', '&3.461E-05', '&5.165672E-05']
# Processed line: &He-3 &2.176E-05 &2.176E-05 &3.461E-05 2.176112e-05
# Raw columns: ['&He-4', '&6.684E-01', '&2.689E+00', '&2.769E-01', '&4.132836E-01']
# Processed line: &He-4 &6.684E-01 &2.689E+00 &2.769E-01 1.779720e+00
# Raw columns: ['&Li-7', '&8.923E-08', '&1.679E-07', '&1.025E-08', '&1.529851E-08']
# Processed line: &Li-7 &8.923E-08 &1.679E-07 &1.025E-08 8.923000e-08
# Raw columns: ['&C-12', '&-1.733E-02', '&7.784E-03', '&3.011E-03', '&4.494030E-03']
# Processed line: &C-12 &-1.733E-02 &7.784E-03 &3.011E-03 -1.729502e-02
# Raw columns: ['&C-13', '&9.459E-04', '&1.248E-03', '&3.411E-05', '&5.091045E-05']
# Processed line: &C-13 &9.459E-04 &1.248E-03 &3.411E-05 9.459635e-04
# Raw columns: ['&N-14', '&4.612E-02', '&5.383E-02', '&8.482E-04', '&1.265970E-03']
# Processed line: &N-14 &4.612E-02 &5.383E-02 &8.482E-04 4.618815e-02
# Raw columns: ['&N-15', '&-2.772E-05', '&2.745E-06', '&2.059E-06', '&3.073134E-06']
# Processed line: &N-15 &-2.772E-05 &2.745E-06 &2.059E-06 -2.771999e-05
# Raw columns: ['&O-16', '&-1.478E-02', '&5.518E-02', '&7.377E-03', '&1.101045E-02']
# Processed line: &O-16 &-1.478E-02 &5.518E-02 &7.377E-03 -1.417244e-02
# Raw columns: ['&O-17', '&2.416E-04', '&2.701E-04', '&2.739E-06', '&4.088060E-06']
# Processed line: &O-17 &2.416E-04 &2.701E-04 &2.739E-06 2.416011e-04
# Raw columns: ['&O-18', '&-1.542E-04', '&4.473E-06', '&1.565E-05', '&2.335821E-05']
# Processed line: &O-18 &-1.542E-04 &4.473E-06 &1.565E-05 -1.541999e-04
# Raw columns: ['&F-19', '&-3.064E-06', '&1.038E-06', '&6.688E-07', '&9.982090E-07']
# Processed line: &F-19 &-3.064E-06 &1.038E-06 &6.688E-07 -3.063999e-06
# Raw columns: ['&Ne-20', '&1.924E-06', '&1.330E-02', '&2.261E-03', '&3.374627E-03']
# Processed line: &Ne-20 &1.924E-06 &1.330E-02 &2.261E-03 4.680654e-05
# Raw columns: ['&Ne-21', '&-2.971E-05', '&4.213E-06', '&5.693E-06', '&8.497015E-06']
# Processed line: &Ne-21 &-2.971E-05 &4.213E-06 &5.693E-06 -2.970996e-05
# Raw columns: ['&Ne-22', '&4.478E-04', '&1.516E-03', '&1.772E-04', '&2.644776E-04']
# Processed line: &Ne-22 &4.478E-04 &1.516E-03 &1.772E-04 4.482009e-04
# Raw columns: ['&Na-23', '&2.527E-04', '&5.450E-04', '&3.692E-05', '&5.510448E-05']
# Processed line: &Na-23 &2.527E-04 &5.450E-04 &3.692E-05 2.527300e-04
# Raw columns: ['&Mg-24', '&-7.312E-04', '&3.555E-03', '&5.398E-04', '&8.056716E-04']
# Processed line: &Mg-24 &-7.312E-04 &3.555E-03 &5.398E-04 -7.283358e-04
# Raw columns: ['&Mg-25', '&8.814E-04', '&1.447E-03', '&7.151E-05', '&1.067313E-04']
# Processed line: &Mg-25 &8.814E-04 &1.447E-03 &7.151E-05 8.815544e-04
# Raw columns: ['&Mg-26', '&5.709E-04', '&1.218E-03', '&8.158E-05', '&1.217612E-04']
# Processed line: &Mg-26 &5.709E-04 &1.218E-03 &8.158E-05 5.710483e-04
# Raw columns: ['&Al-26', '&9.460E-06', '&9.460E-06', '&0.0', '&0.000000E+00']
# Processed line: &Al-26 &9.460E-06 &9.460E-06 &0.0 9.460000e-06
# Raw columns: ['&Al-27', '&1.053E-05', '&4.844E-04', '&6.132E-05', '&9.152239E-05']
# Processed line: &Al-27 &1.053E-05 &4.844E-04 &6.132E-05 1.057433e-05
# Raw columns: ['&Si-28', '&2.337E-05', '&5.472E-03', '&7.167E-04', '&1.069701E-03']
# Processed line: &Si-28 &2.337E-05 &5.472E-03 &7.167E-04 2.922340e-05
# Raw columns: ['&Si-29', '&7.599E-06', '&2.933E-04', '&3.768E-05', '&5.623881E-05']
# Processed line: &Si-29 &7.599E-06 &2.933E-04 &3.768E-05 7.615495e-06
# Raw columns: ['&Si-30', '&1.522E-05', '&2.114E-04', '&2.573E-05', '&3.840299E-05']
# Processed line: &Si-30 &1.522E-05 &2.114E-04 &2.573E-05 1.522812e-05
# Raw columns: ['&P-31', '&3.145E-06', '&5.509E-05', '&7.109E-06', '&1.061045E-05']
# Processed line: &P-31 &3.145E-06 &5.509E-05 &7.109E-06 3.145585e-06
# Raw columns: ['&S-32', '&-9.016E-06', '&3.856E-03', '&3.692E-04', '&5.510448E-04']
# Processed line: &S-32 &-9.016E-06 &3.856E-03 &3.692E-04 -6.891171e-06
# Raw columns: ['&S-33', '&1.504E-07', '&3.162E-05', '&2.996E-06', '&4.471642E-06']
# Processed line: &S-33 &1.504E-07 &3.162E-05 &2.996E-06 1.505414e-07
# Raw columns: ['&S-34', '&-7.326E-06', '&1.566E-03', '&1.727E-05', '&2.577612E-05']
# Processed line: &S-34 &-7.326E-06 &1.566E-03 &1.727E-05 -7.285635e-06
# Raw columns: ['&S-35', '&7.992E-06', '&7.992E-06', '&0.0', '&0.000000E+00']
# Processed line: &S-35 &7.992E-06 &7.992E-06 &0.0 7.992000e-06
# Raw columns: ['&Fe-54', '&-4.676E-06', '&5.844E-04', '&7.643E-05', '&1.140746E-04']
# Processed line: &Fe-54 &-4.676E-06 &5.844E-04 &7.643E-05 -4.609335e-06
# Raw columns: ['&Fe-55', '&1.714E-06', '&1.714E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-55 &1.714E-06 &1.714E-06 &0.0 1.714000e-06
# Raw columns: ['&Fe-56', '&-4.553E-05', '&9.609E-03', '&1.245E-03', '&1.858209E-03']
# Processed line: &Fe-56 &-4.553E-05 &9.609E-03 &1.245E-03 -2.767447e-05
# Raw columns: ['&Fe-57', '&3.394E-06', '&2.392E-04', '&2.927E-05', '&4.368657E-05']
# Processed line: &Fe-57 &3.394E-06 &2.392E-04 &2.927E-05 3.404450e-06
# Raw columns: ['&Fe-58', '&1.255E-05', '&4.309E-05', '&3.960E-06', '&5.910448E-06']
# Processed line: &Fe-58 &1.255E-05 &4.309E-05 &3.960E-06 1.255025e-05
# Raw columns: ['&Fe-60', '&1.419E-05', '&1.419E-05', '&0.0', '&0.000000E+00']
# Processed line: &Fe-60 &1.419E-05 &1.419E-05 &0.0 1.419000e-05
# Raw columns: ['&Co-59', '&6.363E-06', '&3.554E-05', '&3.701E-06', '&5.523881E-06']
# Processed line: &Co-59 &6.363E-06 &3.554E-05 &3.701E-06 6.363196e-06
# Raw columns: ['&Ni-58', '&-2.707E-06', '&4.159E-04', '&5.328E-05', '&7.952239E-05']
# Processed line: &Ni-58 &-2.707E-06 &4.159E-04 &5.328E-05 -2.673927e-06
# Raw columns: ['&Ni-60', '&8.650E-07', '&1.664E-04', '&2.131E-05', '&3.180597E-05']
# Processed line: &Ni-60 &8.650E-07 &1.664E-04 &2.131E-05 8.702925e-07
# Raw columns: ['&Ni-61', '&4.031E-05', '&4.760E-05', '&9.396E-07', '&1.402388E-06']
# Processed line: &Ni-61 &4.031E-05 &4.760E-05 &9.396E-07 4.031007e-05
# Raw columns: ['&Ni-62', '&-2.338E-05', '&1.489E-07', '&3.046E-06', '&4.546269E-06']
# Processed line: &Ni-62 &-2.338E-05 &1.489E-07 &3.046E-06 -2.338000e-05
# Raw columns: ['&Isotopes', '&NetYield', '&MassExp', '&X_i,solar', '&X_i,0', '&Yields']
# Skipping line due to ValueError: &Isotopes &NetYield &MassExp &X_i,solar &X_i,0 &Yields - could not convert string to float: 'NetYield'
# Raw columns: ['&H', '&-7.488E-01', '&4.732E+00', '&7.057E-01', '&1.053284E+00']
# Processed line: &H &-7.488E-01 &4.732E+00 &7.057E-01 4.235340e+00
# Raw columns: ['&He-3', '&2.800E-05', '&2.800E-05', '&3.461E-05', '&5.165672E-05']
# Processed line: &He-3 &2.800E-05 &2.800E-05 &3.461E-05 2.800145e-05
# Raw columns: ['&He-4', '&7.251E-01', '&2.863E+00', '&2.769E-01', '&4.132836E-01']
# Processed line: &He-4 &7.251E-01 &2.863E+00 &2.769E-01 1.908331e+00
# Raw columns: ['&Li-7', '&1.928E-07', '&2.760E-07', '&1.025E-08', '&1.529851E-08']
# Processed line: &Li-7 &1.928E-07 &2.760E-07 &1.025E-08 1.928000e-07
# Raw columns: ['&C-12', '&-1.921E-02', '&7.375E-03', '&3.011E-03', '&4.494030E-03']
# Processed line: &C-12 &-1.921E-02 &7.375E-03 &3.011E-03 -1.917686e-02
# Raw columns: ['&C-13', '&1.171E-03', '&1.490E-03', '&3.411E-05', '&5.091045E-05']
# Processed line: &C-13 &1.171E-03 &1.490E-03 &3.411E-05 1.171076e-03
# Raw columns: ['&N-14', '&5.416E-02', '&6.232E-02', '&8.482E-04', '&1.265970E-03']
# Processed line: &N-14 &5.416E-02 &6.232E-02 &8.482E-04 5.423890e-02
# Raw columns: ['&N-15', '&-2.613E-05', '&6.115E-06', '&2.059E-06', '&3.073134E-06']
# Processed line: &N-15 &-2.613E-05 &6.115E-06 &2.059E-06 -2.612998e-05
# Raw columns: ['&O-16', '&-1.456E-02', '&5.948E-02', '&7.377E-03', '&1.101045E-02']
# Processed line: &O-16 &-1.456E-02 &5.948E-02 &7.377E-03 -1.390510e-02
# Raw columns: ['&O-17', '&3.012E-04', '&3.313E-04', '&2.739E-06', '&4.088060E-06']
# Processed line: &O-17 &3.012E-04 &3.313E-04 &2.739E-06 3.012014e-04
# Raw columns: ['&O-18', '&-1.584E-04', '&9.548E-06', '&1.565E-05', '&2.335821E-05']
# Processed line: &O-18 &-1.584E-04 &9.548E-06 &1.565E-05 -1.583998e-04
# Raw columns: ['&F-19', '&-3.338E-06', '&1.003E-06', '&6.688E-07', '&9.982090E-07']
# Processed line: &F-19 &-3.338E-06 &1.003E-06 &6.688E-07 -3.337999e-06
# Raw columns: ['&Ne-20', '&2.152E-05', '&1.409E-02', '&2.261E-03', '&3.374627E-03']
# Processed line: &Ne-20 &2.152E-05 &1.409E-02 &2.261E-03 6.906849e-05
# Raw columns: ['&Ne-21', '&-3.115E-05', '&4.757E-06', '&5.693E-06', '&8.497015E-06']
# Processed line: &Ne-21 &-3.115E-05 &4.757E-06 &5.693E-06 -3.114996e-05
# Raw columns: ['&Ne-22', '&9.262E-04', '&2.056E-03', '&1.772E-04', '&2.644776E-04']
# Processed line: &Ne-22 &9.262E-04 &2.056E-03 &1.772E-04 9.267438e-04
# Raw columns: ['&Na-23', '&2.633E-04', '&5.727E-04', '&3.692E-05', '&5.510448E-05']
# Processed line: &Na-23 &2.633E-04 &5.727E-04 &3.692E-05 2.633316e-04
# Raw columns: ['&Mg-24', '&-1.296E-03', '&3.240E-03', '&5.398E-04', '&8.056716E-04']
# Processed line: &Mg-24 &-1.296E-03 &3.240E-03 &5.398E-04 -1.293390e-03
# Raw columns: ['&Mg-25', '&1.456E-03', '&2.054E-03', '&7.151E-05', '&1.067313E-04']
# Processed line: &Mg-25 &1.456E-03 &2.054E-03 &7.151E-05 1.456219e-03
# Raw columns: ['&Mg-26', '&5.674E-04', '&1.252E-03', '&8.158E-05', '&1.217612E-04']
# Processed line: &Mg-26 &5.674E-04 &1.252E-03 &8.158E-05 5.675524e-04
# Raw columns: ['&Al-26', '&1.205E-05', '&1.205E-05', '&0.0', '&0.000000E+00']
# Processed line: &Al-26 &1.205E-05 &1.205E-05 &0.0 1.205000e-05
# Raw columns: ['&Al-27', '&1.079E-05', '&5.123E-04', '&6.132E-05', '&9.152239E-05']
# Processed line: &Al-27 &1.079E-05 &5.123E-04 &6.132E-05 1.083689e-05
# Raw columns: ['&Si-28', '&2.043E-05', '&5.787E-03', '&7.167E-04', '&1.069701E-03']
# Processed line: &Si-28 &2.043E-05 &5.787E-03 &7.167E-04 2.662036e-05
# Raw columns: ['&Si-29', '&6.760E-06', '&3.091E-04', '&3.768E-05', '&5.623881E-05']
# Processed line: &Si-29 &6.760E-06 &3.091E-04 &3.768E-05 6.777383e-06
# Raw columns: ['&Si-30', '&1.473E-05', '&2.224E-04', '&2.573E-05', '&3.840299E-05']
# Processed line: &Si-30 &1.473E-05 &2.224E-04 &2.573E-05 1.473854e-05
# Raw columns: ['&P-31', '&3.126E-06', '&5.810E-05', '&7.109E-06', '&1.061045E-05']
# Processed line: &P-31 &3.126E-06 &5.810E-05 &7.109E-06 3.126616e-06
# Raw columns: ['&S-32', '&-7.344E-06', '&4.083E-03', '&3.692E-04', '&5.510448E-04']
# Processed line: &S-32 &-7.344E-06 &4.083E-03 &3.692E-04 -5.094084e-06
# Raw columns: ['&S-33', '&1.619E-07', '&3.346E-05', '&2.996E-06', '&4.471642E-06']
# Processed line: &S-33 &1.619E-07 &3.346E-05 &2.996E-06 1.620496e-07
# Raw columns: ['&S-34', '&-6.744E-06', '&1.659E-03', '&1.727E-05', '&2.577612E-05']
# Processed line: &S-34 &-6.744E-06 &1.659E-03 &1.727E-05 -6.701237e-06
# Raw columns: ['&S-35', '&7.473E-06', '&7.473E-06', '&0.0', '&0.000000E+00']
# Processed line: &S-35 &7.473E-06 &7.473E-06 &0.0 7.473000e-06
# Raw columns: ['&Fe-54', '&-4.744E-06', '&6.187E-04', '&7.643E-05', '&1.140746E-04']
# Processed line: &Fe-54 &-4.744E-06 &6.187E-04 &7.643E-05 -4.673422e-06
# Raw columns: ['&Fe-55', '&2.091E-06', '&2.091E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-55 &2.091E-06 &2.091E-06 &0.0 2.091000e-06
# Raw columns: ['&Fe-56', '&-4.144E-05', '&1.018E-02', '&1.245E-03', '&1.858209E-03']
# Processed line: &Fe-56 &-4.144E-05 &1.018E-02 &1.245E-03 -2.252343e-05
# Raw columns: ['&Fe-57', '&3.808E-06', '&2.534E-04', '&2.927E-05', '&4.368657E-05']
# Processed line: &Fe-57 &3.808E-06 &2.534E-04 &2.927E-05 3.819070e-06
# Raw columns: ['&Fe-58', '&9.907E-06', '&4.222E-05', '&3.960E-06', '&5.910448E-06']
# Processed line: &Fe-58 &9.907E-06 &4.222E-05 &3.960E-06 9.907250e-06
# Raw columns: ['&Fe-60', '&1.365E-05', '&1.365E-05', '&0.0', '&0.000000E+00']
# Processed line: &Fe-60 &1.365E-05 &1.365E-05 &0.0 1.365000e-05
# Raw columns: ['&Co-59', '&5.256E-06', '&3.614E-05', '&3.701E-06', '&5.523881E-06']
# Processed line: &Co-59 &5.256E-06 &3.614E-05 &3.701E-06 5.256200e-06
# Raw columns: ['&Ni-58', '&-2.598E-06', '&4.405E-04', '&5.328E-05', '&7.952239E-05']
# Processed line: &Ni-58 &-2.598E-06 &4.405E-04 &5.328E-05 -2.562970e-06
# Raw columns: ['&Ni-60', '&4.911E-07', '&1.757E-04', '&2.131E-05', '&3.180597E-05']
# Processed line: &Ni-60 &4.911E-07 &1.757E-04 &2.131E-05 4.966883e-07
# Raw columns: ['&Ni-61', '&4.082E-05', '&4.853E-05', '&9.396E-07', '&1.402388E-06']
# Processed line: &Ni-61 &4.082E-05 &4.853E-05 &9.396E-07 4.082007e-05
# Raw columns: ['&Ni-62', '&-2.475E-05', '&1.559E-07', '&3.046E-06', '&4.546269E-06']
# Processed line: &Ni-62 &-2.475E-05 &1.559E-07 &3.046E-06 -2.475000e-05
# Raw columns: ['&Isotopes', '&NetYield', '&MassExp', '&X_i,solar', '&X_i,0', '&Yields']
# Skipping line due to ValueError: &Isotopes &NetYield &MassExp &X_i,solar &X_i,0 &Yields - could not convert string to float: 'NetYield'
# Raw columns: ['&H', '&-4.908E-01', '&3.577E+00', '&7.057E-01', '&4.213134E-01']
# Processed line: &H &-4.908E-01 &3.577E+00 &7.057E-01 1.016238e+00
# Raw columns: ['&He-3', '&4.836E-06', '&4.836E-06', '&3.461E-05', '&2.066269E-05']
# Processed line: &He-3 &4.836E-06 &4.836E-06 &3.461E-05 4.836100e-06
# Raw columns: ['&He-4', '&4.573E-01', '&1.892E+00', '&2.769E-01', '&1.653134E-01']
# Processed line: &He-4 &4.573E-01 &1.892E+00 &2.769E-01 7.700730e-01
# Raw columns: ['&Li-7', '&-2.346E-08', '&2.999E-10', '&1.025E-08', '&6.119403E-09']
# Processed line: &Li-7 &-2.346E-08 &2.999E-10 &1.025E-08 -2.346000e-08
# Raw columns: ['&C-12', '&-2.226E-03', '&5.664E-03', '&3.011E-03', '&1.797612E-03']
# Processed line: &C-12 &-2.226E-03 &5.664E-03 &3.011E-03 -2.215818e-03
# Raw columns: ['&C-13', '&5.583E-04', '&6.495E-04', '&3.411E-05', '&2.036418E-05']
# Processed line: &C-13 &5.583E-04 &6.495E-04 &3.411E-05 5.583132e-04
# Raw columns: ['&N-14', '&4.088E-02', '&4.330E-02', '&8.482E-04', '&5.063881E-04']
# Processed line: &N-14 &4.088E-02 &4.330E-02 &8.482E-04 4.090193e-02
# Raw columns: ['&N-15', '&-8.058E-06', '&1.144E-06', '&2.059E-06', '&1.229254E-06']
# Processed line: &N-15 &-8.058E-06 &1.144E-06 &2.059E-06 -8.057999e-06
# Raw columns: ['&O-16', '&-7.190E-03', '&1.479E-02', '&7.377E-03', '&4.404179E-03']
# Processed line: &O-16 &-7.190E-03 &1.479E-02 &7.377E-03 -7.124862e-03
# Raw columns: ['&O-17', '&3.475E-05', '&4.335E-05', '&2.739E-06', '&1.635224E-06']
# Processed line: &O-17 &3.475E-05 &4.335E-05 &2.739E-06 3.475007e-05
# Raw columns: ['&O-18', '&-4.674E-05', '&1.186E-06', '&1.565E-05', '&9.343284E-06']
# Processed line: &O-18 &-4.674E-05 &1.186E-06 &1.565E-05 -4.673999e-05
# Raw columns: ['&F-19', '&-4.210E-07', '&8.174E-07', '&6.688E-07', '&3.992836E-07']
# Processed line: &F-19 &-4.210E-07 &8.174E-07 &6.688E-07 -4.209997e-07
# Raw columns: ['&Ne-20', '&2.085E-06', '&4.017E-03', '&2.261E-03', '&1.349851E-03']
# Processed line: &Ne-20 &2.085E-06 &4.017E-03 &2.261E-03 7.507351e-06
# Raw columns: ['&Ne-21', '&-9.255E-06', '&9.921E-07', '&5.693E-06', '&3.398806E-06']
# Processed line: &Ne-21 &-9.255E-06 &9.921E-07 &5.693E-06 -9.254997e-06
# Raw columns: ['&Ne-22', '&9.095E-04', '&1.232E-03', '&1.772E-04', '&1.057910E-04']
# Processed line: &Ne-22 &9.095E-04 &1.232E-03 &1.772E-04 9.096303e-04
# Raw columns: ['&Na-23', '&6.146E-05', '&1.498E-04', '&3.692E-05', '&2.204179E-05']
# Processed line: &Na-23 &6.146E-05 &1.498E-04 &3.692E-05 6.146330e-05
# Raw columns: ['&Mg-24', '&-2.524E-04', '&1.042E-03', '&5.398E-04', '&3.222687E-04']
# Processed line: &Mg-24 &-2.524E-04 &1.042E-03 &5.398E-04 -2.520642e-04
# Raw columns: ['&Mg-25', '&3.642E-04', '&5.349E-04', '&7.151E-05', '&4.269254E-05']
# Processed line: &Mg-25 &3.642E-04 &5.349E-04 &7.151E-05 3.642228e-04
# Raw columns: ['&Mg-26', '&3.369E-04', '&5.323E-04', '&8.158E-05', '&4.870448E-05']
# Processed line: &Mg-26 &3.369E-04 &5.323E-04 &8.158E-05 3.369259e-04
# Raw columns: ['&Al-26', '&1.327E-05', '&1.327E-05', '&0.0', '&0.000000E+00']
# Processed line: &Al-26 &1.327E-05 &1.327E-05 &0.0 1.327000e-05
# Raw columns: ['&Al-27', '&1.540E-05', '&1.585E-04', '&6.132E-05', '&3.660896E-05']
# Processed line: &Al-27 &1.540E-05 &1.585E-04 &6.132E-05 1.540580e-05
# Raw columns: ['&Si-28', '&2.867E-05', '&1.673E-03', '&7.167E-04', '&4.278806E-04']
# Processed line: &Si-28 &2.867E-05 &1.673E-03 &7.167E-04 2.938584e-05
# Raw columns: ['&Si-29', '&5.820E-06', '&9.212E-05', '&3.768E-05', '&2.249552E-05']
# Processed line: &Si-29 &5.820E-06 &9.212E-05 &3.768E-05 5.822072e-06
# Raw columns: ['&Si-30', '&9.807E-06', '&6.906E-05', '&2.573E-05', '&1.536119E-05']
# Processed line: &Si-30 &9.807E-06 &6.906E-05 &2.573E-05 9.808061e-06
# Raw columns: ['&P-31', '&1.758E-06', '&1.745E-05', '&7.109E-06', '&4.244179E-06']
# Processed line: &P-31 &1.758E-06 &1.745E-05 &7.109E-06 1.758074e-06
# Raw columns: ['&S-32', '&-6.732E-06', '&1.161E-03', '&3.692E-04', '&2.204179E-04']
# Processed line: &S-32 &-6.732E-06 &1.161E-03 &3.692E-04 -6.476095e-06
# Raw columns: ['&S-33', '&1.526E-07', '&9.655E-06', '&2.996E-06', '&1.788657E-06']
# Processed line: &S-33 &1.526E-07 &9.655E-06 &2.996E-06 1.526173e-07
# Raw columns: ['&S-34', '&-5.720E-06', '&4.695E-04', '&1.727E-05', '&1.031045E-05']
# Processed line: &S-34 &-5.720E-06 &4.695E-04 &1.727E-05 -5.715159e-06
# Raw columns: ['&S-35', '&6.275E-06', '&6.275E-06', '&0.0', '&0.000000E+00']
# Processed line: &S-35 &6.275E-06 &6.275E-06 &0.0 6.275000e-06
# Raw columns: ['&Fe-54', '&-3.430E-06', '&1.744E-04', '&7.643E-05', '&4.562985E-05']
# Processed line: &Fe-54 &-3.430E-06 &1.744E-04 &7.643E-05 -3.422042e-06
# Raw columns: ['&Fe-55', '&4.420E-07', '&4.420E-07', '&0.0', '&0.000000E+00']
# Processed line: &Fe-55 &4.420E-07 &4.420E-07 &0.0 4.420000e-07
# Raw columns: ['&Fe-56', '&-3.857E-05', '&2.878E-03', '&1.245E-03', '&7.432836E-04']
# Processed line: &Fe-56 &-3.857E-05 &2.878E-03 &1.245E-03 -3.643083e-05
# Raw columns: ['&Fe-57', '&4.053E-06', '&7.526E-05', '&2.927E-05', '&1.747463E-05']
# Processed line: &Fe-57 &4.053E-06 &7.526E-05 &2.927E-05 4.054315e-06
# Raw columns: ['&Fe-58', '&1.674E-05', '&2.597E-05', '&3.960E-06', '&2.364179E-06']
# Processed line: &Fe-58 &1.674E-05 &2.597E-05 &3.960E-06 1.674006e-05
# Raw columns: ['&Fe-60', '&6.504E-06', '&6.504E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-60 &6.504E-06 &6.504E-06 &0.0 6.504000e-06
# Raw columns: ['&Co-59', '&6.020E-06', '&1.483E-05', '&3.701E-06', '&2.209552E-06']
# Processed line: &Co-59 &6.020E-06 &1.483E-05 &3.701E-06 6.020033e-06
# Raw columns: ['&Ni-58', '&-2.351E-06', '&1.241E-04', '&5.328E-05', '&3.180896E-05']
# Processed line: &Ni-58 &-2.351E-06 &1.241E-04 &5.328E-05 -2.347053e-06
# Raw columns: ['&Ni-60', '&1.556E-06', '&5.158E-05', '&2.131E-05', '&1.272239E-05']
# Processed line: &Ni-60 &1.556E-06 &5.158E-05 &2.131E-05 1.556656e-06
# Raw columns: ['&Ni-61', '&1.844E-05', '&2.065E-05', '&9.396E-07', '&5.609552E-07']
# Processed line: &Ni-61 &1.844E-05 &2.065E-05 &9.396E-07 1.844001e-05
# Raw columns: ['&Ni-62', '&-7.053E-06', '&5.531E-08', '&3.046E-06', '&1.818507E-06']
# Processed line: &Ni-62 &-7.053E-06 &5.531E-08 &3.046E-06 -7.053000e-06
# Raw columns: ['&Isotopes', '&NetYield', '&MassExp', '&X_i,solar', '&X_i,0', '&Yields']
# Skipping line due to ValueError: &Isotopes &NetYield &MassExp &X_i,solar &X_i,0 &Yields - could not convert string to float: 'NetYield'
# Raw columns: ['&H', '&-5.298E-01', '&3.870E+00', '&7.057E-01', '&4.213134E-01']
# Processed line: &H &-5.298E-01 &3.870E+00 &7.057E-01 1.100683e+00
# Raw columns: ['&He-3', '&4.827E-06', '&4.827E-06', '&3.461E-05', '&2.066269E-05']
# Processed line: &He-3 &4.827E-06 &4.827E-06 &3.461E-05 4.827100e-06
# Raw columns: ['&He-4', '&5.096E-01', '&2.062E+00', '&2.769E-01', '&1.653134E-01']
# Processed line: &He-4 &5.096E-01 &2.062E+00 &2.769E-01 8.504762e-01
# Raw columns: ['&Li-7', '&-2.510E-08', '&5.966E-10', '&1.025E-08', '&6.119403E-09']
# Processed line: &Li-7 &-2.510E-08 &5.966E-10 &1.025E-08 -2.510000e-08
# Raw columns: ['&C-12', '&-3.712E-03', '&4.822E-03', '&3.011E-03', '&1.797612E-03']
# Processed line: &C-12 &-3.712E-03 &4.822E-03 &3.011E-03 -3.703332e-03
# Raw columns: ['&C-13', '&4.587E-04', '&5.573E-04', '&3.411E-05', '&2.036418E-05']
# Processed line: &C-13 &4.587E-04 &5.573E-04 &3.411E-05 4.587113e-04
# Raw columns: ['&N-14', '&3.028E-02', '&3.290E-02', '&8.482E-04', '&5.063881E-04']
# Processed line: &N-14 &3.028E-02 &3.290E-02 &8.482E-04 3.029666e-02
# Raw columns: ['&N-15', '&-8.888E-06', '&1.066E-06', '&2.059E-06', '&1.229254E-06']
# Processed line: &N-15 &-8.888E-06 &1.066E-06 &2.059E-06 -8.887999e-06
# Raw columns: ['&O-16', '&-7.595E-03', '&1.618E-02', '&7.377E-03', '&4.404179E-03']
# Processed line: &O-16 &-7.595E-03 &1.618E-02 &7.377E-03 -7.523740e-03
# Raw columns: ['&O-17', '&4.897E-05', '&5.827E-05', '&2.739E-06', '&1.635224E-06']
# Processed line: &O-17 &4.897E-05 &5.827E-05 &2.739E-06 4.897010e-05
# Raw columns: ['&O-18', '&-5.051E-05', '&1.328E-06', '&1.565E-05', '&9.343284E-06']
# Processed line: &O-18 &-5.051E-05 &1.328E-06 &1.565E-05 -5.050999e-05
# Raw columns: ['&F-19', '&-8.383E-07', '&5.011E-07', '&6.688E-07', '&3.992836E-07']
# Processed line: &F-19 &-8.383E-07 &5.011E-07 &6.688E-07 -8.382998e-07
# Raw columns: ['&Ne-20', '&2.668E-06', '&4.345E-03', '&2.261E-03', '&1.349851E-03']
# Processed line: &Ne-20 &2.668E-06 &4.345E-03 &2.261E-03 8.533103e-06
# Raw columns: ['&Ne-21', '&-1.024E-05', '&8.442E-07', '&5.693E-06', '&3.398806E-06']
# Processed line: &Ne-21 &-1.024E-05 &8.442E-07 &5.693E-06 -1.024000e-05
# Raw columns: ['&Ne-22', '&4.251E-04', '&7.740E-04', '&1.772E-04', '&1.057910E-04']
# Processed line: &Ne-22 &4.251E-04 &7.740E-04 &1.772E-04 4.251819e-04
# Raw columns: ['&Na-23', '&5.816E-05', '&1.537E-04', '&3.692E-05', '&2.204179E-05']
# Processed line: &Na-23 &5.816E-05 &1.537E-04 &3.692E-05 5.816339e-05
# Raw columns: ['&Mg-24', '&-4.514E-04', '&9.486E-04', '&5.398E-04', '&3.222687E-04']
# Processed line: &Mg-24 &-4.514E-04 &9.486E-04 &5.398E-04 -4.510943e-04
# Raw columns: ['&Mg-25', '&5.086E-04', '&6.933E-04', '&7.151E-05', '&4.269254E-05']
# Processed line: &Mg-25 &5.086E-04 &6.933E-04 &7.151E-05 5.086296e-04
# Raw columns: ['&Mg-26', '&2.049E-04', '&4.162E-04', '&8.158E-05', '&4.870448E-05']
# Processed line: &Mg-26 &2.049E-04 &4.162E-04 &8.158E-05 2.049203e-04
# Raw columns: ['&Al-26', '&1.510E-05', '&1.510E-05', '&0.0', '&0.000000E+00']
# Processed line: &Al-26 &1.510E-05 &1.510E-05 &0.0 1.510000e-05
# Raw columns: ['&Al-27', '&9.430E-06', '&1.642E-04', '&6.132E-05', '&3.660896E-05']
# Processed line: &Al-27 &9.430E-06 &1.642E-04 &6.132E-05 9.436011e-06
# Raw columns: ['&Si-28', '&1.983E-05', '&1.799E-03', '&7.167E-04', '&4.278806E-04']
# Processed line: &Si-28 &1.983E-05 &1.799E-03 &7.167E-04 2.059976e-05
# Raw columns: ['&Si-29', '&3.799E-06', '&9.715E-05', '&3.768E-05', '&2.249552E-05']
# Processed line: &Si-29 &3.799E-06 &9.715E-05 &3.768E-05 3.801185e-06
# Raw columns: ['&Si-30', '&6.273E-06', '&7.037E-05', '&2.573E-05', '&1.536119E-05']
# Processed line: &Si-30 &6.273E-06 &7.037E-05 &2.573E-05 6.274081e-06
# Raw columns: ['&P-31', '&1.130E-06', '&1.810E-05', '&7.109E-06', '&4.244179E-06']
# Processed line: &P-31 &1.130E-06 &1.810E-05 &7.109E-06 1.130077e-06
# Raw columns: ['&S-32', '&-4.186E-06', '&1.259E-03', '&3.692E-04', '&2.204179E-04']
# Processed line: &S-32 &-4.186E-06 &1.259E-03 &3.692E-04 -3.908494e-06
# Raw columns: ['&S-33', '&9.646E-08', '&1.037E-05', '&2.996E-06', '&1.788657E-06']
# Processed line: &S-33 &9.646E-08 &1.037E-05 &2.996E-06 9.647855e-08
# Raw columns: ['&S-34', '&-3.632E-06', '&5.104E-04', '&1.727E-05', '&1.031045E-05']
# Processed line: &S-34 &-3.632E-06 &5.104E-04 &1.727E-05 -3.626738e-06
# Raw columns: ['&S-35', '&3.979E-06', '&3.979E-06', '&0.0', '&0.000000E+00']
# Processed line: &S-35 &3.979E-06 &3.979E-06 &0.0 3.979000e-06
# Raw columns: ['&Fe-54', '&-2.344E-06', '&1.900E-04', '&7.643E-05', '&4.562985E-05']
# Processed line: &Fe-54 &-2.344E-06 &1.900E-04 &7.643E-05 -2.335330e-06
# Raw columns: ['&Fe-55', '&5.263E-07', '&5.263E-07', '&0.0', '&0.000000E+00']
# Processed line: &Fe-55 &5.263E-07 &5.263E-07 &0.0 5.263000e-07
# Raw columns: ['&Fe-56', '&-2.395E-05', '&3.131E-03', '&1.245E-03', '&7.432836E-04']
# Processed line: &Fe-56 &-2.395E-05 &3.131E-03 &1.245E-03 -2.162278e-05
# Raw columns: ['&Fe-57', '&2.745E-06', '&7.976E-05', '&2.927E-05', '&1.747463E-05']
# Processed line: &Fe-57 &2.745E-06 &7.976E-05 &2.927E-05 2.746394e-06
# Raw columns: ['&Fe-58', '&1.011E-05', '&2.009E-05', '&3.960E-06', '&2.364179E-06']
# Processed line: &Fe-58 &1.011E-05 &2.009E-05 &3.960E-06 1.011005e-05
# Raw columns: ['&Fe-60', '&4.285E-06', '&4.285E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-60 &4.285E-06 &4.285E-06 &0.0 4.285000e-06
# Raw columns: ['&Co-59', '&3.734E-06', '&1.327E-05', '&3.701E-06', '&2.209552E-06']
# Processed line: &Co-59 &3.734E-06 &1.327E-05 &3.701E-06 3.734029e-06
# Raw columns: ['&Ni-58', '&-1.512E-06', '&1.352E-04', '&5.328E-05', '&3.180896E-05']
# Processed line: &Ni-58 &-1.512E-06 &1.352E-04 &5.328E-05 -1.507699e-06
# Raw columns: ['&Ni-60', '&8.751E-07', '&5.498E-05', '&2.131E-05', '&1.272239E-05']
# Processed line: &Ni-60 &8.751E-07 &5.498E-05 &2.131E-05 8.757995e-07
# Raw columns: ['&Ni-61', '&1.461E-05', '&1.699E-05', '&9.396E-07', '&5.609552E-07']
# Processed line: &Ni-61 &1.461E-05 &1.699E-05 &9.396E-07 1.461001e-05
# Raw columns: ['&Ni-62', '&-7.630E-06', '&5.893E-08', '&3.046E-06', '&1.818507E-06']
# Processed line: &Ni-62 &-7.630E-06 &5.893E-08 &3.046E-06 -7.630000e-06
# Raw columns: ['&Isotopes', '&NetYield', '&MassExp', '&X_i,solar', '&X_i,0', '&Yields']
# Skipping line due to ValueError: &Isotopes &NetYield &MassExp &X_i,solar &X_i,0 &Yields - could not convert string to float: 'NetYield'
# Raw columns: ['&H', '&-5.790E-01', '&4.144E+00', '&7.057E-01', '&4.213134E-01']
# Processed line: &H &-5.790E-01 &4.144E+00 &7.057E-01 1.166923e+00
# Raw columns: ['&He-3', '&5.558E-06', '&5.558E-06', '&3.461E-05', '&2.066269E-05']
# Processed line: &He-3 &5.558E-06 &5.558E-06 &3.461E-05 5.558115e-06
# Raw columns: ['&He-4', '&5.635E-01', '&2.230E+00', '&2.769E-01', '&1.653134E-01']
# Processed line: &He-4 &5.635E-01 &2.230E+00 &2.769E-01 9.321489e-01
# Raw columns: ['&Li-7', '&-1.990E-08', '&7.687E-09', '&1.025E-08', '&6.119403E-09']
# Processed line: &Li-7 &-1.990E-08 &7.687E-09 &1.025E-08 -1.990000e-08
# Raw columns: ['&C-12', '&-4.490E-03', '&4.673E-03', '&3.011E-03', '&1.797612E-03']
# Processed line: &C-12 &-4.490E-03 &4.673E-03 &3.011E-03 -4.481600e-03
# Raw columns: ['&C-13', '&5.014E-04', '&6.072E-04', '&3.411E-05', '&2.036418E-05']
# Processed line: &C-13 &5.014E-04 &6.072E-04 &3.411E-05 5.014124e-04
# Raw columns: ['&N-14', '&2.588E-02', '&2.870E-02', '&8.482E-04', '&5.063881E-04']
# Processed line: &N-14 &2.588E-02 &2.870E-02 &8.482E-04 2.589453e-02
# Raw columns: ['&N-15', '&-9.539E-06', '&1.147E-06', '&2.059E-06', '&1.229254E-06']
# Processed line: &N-15 &-9.539E-06 &1.147E-06 &2.059E-06 -9.538999e-06
# Raw columns: ['&O-16', '&-7.126E-03', '&1.840E-02', '&7.377E-03', '&4.404179E-03']
# Processed line: &O-16 &-7.126E-03 &1.840E-02 &7.377E-03 -7.044963e-03
# Raw columns: ['&O-17', '&7.111E-05', '&8.110E-05', '&2.739E-06', '&1.635224E-06']
# Processed line: &O-17 &7.111E-05 &8.110E-05 &2.739E-06 7.111013e-05
# Raw columns: ['&O-18', '&-5.418E-05', '&1.475E-06', '&1.565E-05', '&9.343284E-06']
# Processed line: &O-18 &-5.418E-05 &1.475E-06 &1.565E-05 -5.417999e-05
# Raw columns: ['&F-19', '&-1.136E-06', '&3.019E-07', '&6.688E-07', '&3.992836E-07']
# Processed line: &F-19 &-1.136E-06 &3.019E-07 &6.688E-07 -1.136000e-06
# Raw columns: ['&Ne-20', '&5.876E-06', '&4.668E-03', '&2.261E-03', '&1.349851E-03']
# Processed line: &Ne-20 &5.876E-06 &4.668E-03 &2.261E-03 1.217710e-05
# Raw columns: ['&Ne-21', '&-1.100E-05', '&9.010E-07', '&5.693E-06', '&3.398806E-06']
# Processed line: &Ne-21 &-1.100E-05 &9.010E-07 &5.693E-06 -1.100000e-05
# Raw columns: ['&Ne-22', '&2.632E-04', '&6.378E-04', '&1.772E-04', '&1.057910E-04']
# Processed line: &Ne-22 &2.632E-04 &6.378E-04 &1.772E-04 2.632675e-04
# Raw columns: ['&Na-23', '&6.742E-05', '&1.700E-04', '&3.692E-05', '&2.204179E-05']
# Processed line: &Na-23 &6.742E-05 &1.700E-04 &3.692E-05 6.742375e-05
# Raw columns: ['&Mg-24', '&-5.984E-04', '&9.045E-04', '&5.398E-04', '&3.222687E-04']
# Processed line: &Mg-24 &-5.984E-04 &9.045E-04 &5.398E-04 -5.981085e-04
# Raw columns: ['&Mg-25', '&6.562E-04', '&8.544E-04', '&7.151E-05', '&4.269254E-05']
# Processed line: &Mg-25 &6.562E-04 &8.544E-04 &7.151E-05 6.562365e-04
# Raw columns: ['&Mg-26', '&2.076E-04', '&4.345E-04', '&8.158E-05', '&4.870448E-05']
# Processed line: &Mg-26 &2.076E-04 &4.345E-04 &8.158E-05 2.076212e-04
# Raw columns: ['&Al-26', '&1.348E-05', '&1.348E-05', '&0.0', '&0.000000E+00']
# Processed line: &Al-26 &1.348E-05 &1.348E-05 &0.0 1.348000e-05
# Raw columns: ['&Al-27', '&7.898E-06', '&1.741E-04', '&6.132E-05', '&3.660896E-05']
# Processed line: &Al-27 &7.898E-06 &1.741E-04 &6.132E-05 7.904374e-06
# Raw columns: ['&Si-28', '&1.401E-05', '&1.924E-03', '&7.167E-04', '&4.278806E-04']
# Processed line: &Si-28 &1.401E-05 &1.924E-03 &7.167E-04 1.483324e-05
# Raw columns: ['&Si-29', '&3.096E-06', '&1.033E-04', '&3.768E-05', '&2.249552E-05']
# Processed line: &Si-29 &3.096E-06 &1.033E-04 &3.768E-05 3.098324e-06
# Raw columns: ['&Si-30', '&5.722E-06', '&7.453E-05', '&2.573E-05', '&1.536119E-05']
# Processed line: &Si-30 &5.722E-06 &7.453E-05 &2.573E-05 5.723145e-06
# Raw columns: ['&P-31', '&1.186E-06', '&1.941E-05', '&7.109E-06', '&4.244179E-06']
# Processed line: &P-31 &1.186E-06 &1.941E-05 &7.109E-06 1.186082e-06
# Raw columns: ['&S-32', '&-3.480E-06', '&1.352E-03', '&3.692E-04', '&2.204179E-04']
# Processed line: &S-32 &-3.480E-06 &1.352E-03 &3.692E-04 -3.181995e-06
# ...
# Raw columns: ['&Mg-25', '&6.227E-04', '&7.140E-04', '&7.151E-05', '&2.134627E-05']
# Processed line: &Mg-25 &6.227E-04 &7.140E-04 &7.151E-05 6.227152e-04
# Raw columns: ['&Mg-26', '&1.279E-04', '&2.325E-04', '&8.158E-05', '&2.435224E-05']
# Processed line: &Mg-26 &1.279E-04 &2.325E-04 &8.158E-05 1.279057e-04
# Raw columns: ['&Al-26', '&2.493E-05', '&2.493E-05', '&0.0', '&0.000000E+00']
# Processed line: &Al-26 &2.493E-05 &2.493E-05 &0.0 2.493000e-05
# Raw columns: ['&Al-27', '&1.096E-05', '&8.752E-05', '&6.132E-05', '&1.830448E-05']
# Processed line: &Al-27 &1.096E-05 &8.752E-05 &6.132E-05 1.096160e-05
# Raw columns: ['&Si-28', '&1.020E-05', '&8.906E-04', '&7.167E-04', '&2.139403E-04']
# Processed line: &Si-28 &1.020E-05 &8.906E-04 &7.167E-04 1.039054e-05
# Raw columns: ['&Si-29', '&1.717E-06', '&4.788E-05', '&3.768E-05', '&1.124776E-05']
# Processed line: &Si-29 &1.717E-06 &4.788E-05 &3.768E-05 1.717539e-06
# Raw columns: ['&Si-30', '&3.219E-06', '&3.492E-05', '&2.573E-05', '&7.680597E-06']
# Processed line: &Si-30 &3.219E-06 &3.492E-05 &2.573E-05 3.219268e-06
# Raw columns: ['&P-31', '&7.106E-07', '&9.105E-06', '&7.109E-06', '&2.122090E-06']
# Processed line: &P-31 &7.106E-07 &9.105E-06 &7.109E-06 7.106193e-07
# Raw columns: ['&S-32', '&-1.826E-06', '&6.227E-04', '&3.692E-04', '&1.102090E-04']
# Processed line: &S-32 &-1.826E-06 &6.227E-04 &3.692E-04 -1.757373e-06
# Raw columns: ['&S-33', '&3.068E-08', '&5.114E-06', '&2.996E-06', '&8.943284E-07']
# Processed line: &S-33 &3.068E-08 &5.114E-06 &2.996E-06 3.068457e-08
# Raw columns: ['&S-34', '&-1.498E-06', '&2.528E-04', '&1.727E-05', '&5.155224E-06']
# Processed line: &S-34 &-1.498E-06 &2.528E-04 &1.727E-05 -1.496697e-06
# Raw columns: ['&S-35', '&1.656E-06', '&1.656E-06', '&0.0', '&0.000000E+00']
# Processed line: &S-35 &1.656E-06 &1.656E-06 &0.0 1.656000e-06
# Raw columns: ['&Fe-54', '&-9.730E-07', '&9.419E-05', '&7.643E-05', '&2.281493E-05']
# Processed line: &Fe-54 &-9.730E-07 &9.419E-05 &7.643E-05 -9.708511e-07
# Raw columns: ['&Fe-55', '&3.170E-07', '&3.170E-07', '&0.0', '&0.000000E+00']
# Processed line: &Fe-55 &3.170E-07 &3.170E-07 &0.0 3.170000e-07
# Raw columns: ['&Fe-56', '&-9.526E-06', '&1.551E-03', '&1.245E-03', '&3.716418E-04']
# Processed line: &Fe-56 &-9.526E-06 &1.551E-03 &1.245E-03 -8.949584e-06
# Raw columns: ['&Fe-57', '&8.467E-07', '&3.894E-05', '&2.927E-05', '&8.737313E-06']
# Processed line: &Fe-57 &8.467E-07 &3.894E-05 &2.927E-05 8.470402e-07
# Raw columns: ['&Fe-58', '&2.974E-06', '&7.908E-06', '&3.960E-06', '&1.182090E-06']
# Processed line: &Fe-58 &2.974E-06 &7.908E-06 &3.960E-06 2.974009e-06
# Raw columns: ['&Fe-60', '&2.386E-06', '&2.386E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-60 &2.386E-06 &2.386E-06 &0.0 2.386000e-06
# Raw columns: ['&Co-59', '&1.264E-06', '&5.978E-06', '&3.701E-06', '&1.104776E-06']
# Processed line: &Co-59 &1.264E-06 &5.978E-06 &3.701E-06 1.264007e-06
# Raw columns: ['&Ni-58', '&-5.783E-07', '&6.707E-05', '&5.328E-05', '&1.590448E-05']
# Processed line: &Ni-58 &-5.783E-07 &6.707E-05 &5.328E-05 -5.772333e-07
# Raw columns: ['&Ni-60', '&2.527E-07', '&2.701E-05', '&2.131E-05', '&6.361194E-06']
# Processed line: &Ni-60 &2.527E-07 &2.701E-05 &2.131E-05 2.528718e-07
# Raw columns: ['&Ni-61', '&7.438E-06', '&8.615E-06', '&9.396E-07', '&2.804776E-07']
# Processed line: &Ni-61 &7.438E-06 &8.615E-06 &9.396E-07 7.438002e-06
# Raw columns: ['&Ni-62', '&-3.777E-06', '&2.441E-08', '&3.046E-06', '&9.092537E-07']
# Processed line: &Ni-62 &-3.777E-06 &2.441E-08 &3.046E-06 -3.777000e-06
# Raw columns: ['&Isotopes', '&NetYield', '&MassExp', '&X_i,solar', '&X_i,0', '&Yields']
# Skipping line due to ValueError: &Isotopes &NetYield &MassExp &X_i,solar &X_i,0 &Yields - could not convert string to float: 'NetYield'
# Raw columns: ['&H', '&-6.247E-01', '&4.085E+00', '&7.057E-01', '&2.106567E-01']
# Processed line: &H &-6.247E-01 &4.085E+00 &7.057E-01 2.358326e-01
# Raw columns: ['&He-3', '&6.000E-06', '&6.000E-06', '&3.461E-05', '&1.033134E-05']
# Processed line: &He-3 &6.000E-06 &6.000E-06 &3.461E-05 6.000062e-06
# Raw columns: ['&He-4', '&6.119E-01', '&2.218E+00', '&2.769E-01', '&8.265672E-02']
# Processed line: &He-4 &6.119E-01 &2.218E+00 &2.769E-01 7.952326e-01
# Raw columns: ['&Li-7', '&1.249E-08', '&2.607E-08', '&1.025E-08', '&3.059701E-09']
# Processed line: &Li-7 &1.249E-08 &2.607E-08 &1.025E-08 1.249000e-08
# Raw columns: ['&C-12', '&-1.164E-03', '&3.404E-03', '&3.011E-03', '&8.988060E-04']
# Processed line: &C-12 &-1.164E-03 &3.404E-03 &3.011E-03 -1.160940e-03
# Raw columns: ['&C-13', '&3.758E-04', '&4.279E-04', '&3.411E-05', '&1.018209E-05']
# Processed line: &C-13 &3.758E-04 &4.279E-04 &3.411E-05 3.758044e-04
# Raw columns: ['&N-14', '&1.777E-02', '&1.918E-02', '&8.482E-04', '&2.531940E-04']
# Processed line: &N-14 &1.777E-02 &1.918E-02 &8.482E-04 1.777486e-02
# Raw columns: ['&N-15', '&-3.940E-06', '&1.319E-06', '&2.059E-06', '&6.146269E-07']
# Processed line: &N-15 &-3.940E-06 &1.319E-06 &2.059E-06 -3.939999e-06
# Raw columns: ['&O-16', '&-4.503E-03', '&8.223E-03', '&7.377E-03', '&2.202090E-03']
# Processed line: &O-16 &-4.503E-03 &8.223E-03 &7.377E-03 -4.484892e-03
# Raw columns: ['&O-17', '&4.393E-05', '&4.885E-05', '&2.739E-06', '&8.176119E-07']
# Processed line: &O-17 &4.393E-05 &4.885E-05 &2.739E-06 4.393004e-05
# Raw columns: ['&O-18', '&-2.682E-05', '&5.752E-07', '&1.565E-05', '&4.671642E-06']
# Processed line: &O-18 &-2.682E-05 &5.752E-07 &1.565E-05 -2.682000e-05
# Raw columns: ['&F-19', '&-6.282E-07', '&7.989E-08', '&6.688E-07', '&1.996418E-07']
# Processed line: &F-19 &-6.282E-07 &7.989E-08 &6.688E-07 -6.282000e-07
# Raw columns: ['&Ne-20', '&3.798E-05', '&2.334E-03', '&2.261E-03', '&6.749254E-04']
# Processed line: &Ne-20 &3.798E-05 &2.334E-03 &2.261E-03 3.955528e-05
# Raw columns: ['&Ne-21', '&-5.439E-06', '&4.180E-07', '&5.693E-06', '&1.699403E-06']
# Processed line: &Ne-21 &-5.439E-06 &4.180E-07 &5.693E-06 -5.438999e-06
# Raw columns: ['&Ne-22', '&1.442E-04', '&3.285E-04', '&1.772E-04', '&5.289552E-05']
# Processed line: &Ne-22 &1.442E-04 &3.285E-04 &1.772E-04 1.442174e-04
# Raw columns: ['&Na-23', '&3.455E-06', '&5.394E-05', '&3.692E-05', '&1.102090E-05']
# Processed line: &Na-23 &3.455E-06 &5.394E-05 &3.692E-05 3.455594e-06
# Raw columns: ['&Mg-24', '&-6.531E-04', '&8.672E-05', '&5.398E-04', '&1.611343E-04']
# Processed line: &Mg-24 &-6.531E-04 &8.672E-05 &5.398E-04 -6.530860e-04
# Raw columns: ['&Mg-25', '&6.887E-04', '&7.862E-04', '&7.151E-05', '&2.134627E-05']
# Processed line: &Mg-25 &6.887E-04 &7.862E-04 &7.151E-05 6.887168e-04
# Raw columns: ['&Mg-26', '&1.381E-04', '&2.499E-04', '&8.158E-05', '&2.435224E-05']
# Processed line: &Mg-26 &1.381E-04 &2.499E-04 &8.158E-05 1.381061e-04
# Raw columns: ['&Al-26', '&1.995E-05', '&1.995E-05', '&0.0', '&0.000000E+00']
# Processed line: &Al-26 &1.995E-05 &1.995E-05 &0.0 1.995000e-05
# Raw columns: ['&Al-27', '&1.140E-05', '&9.320E-05', '&6.132E-05', '&1.830448E-05']
# Processed line: &Al-27 &1.140E-05 &9.320E-05 &6.132E-05 1.140171e-05
# Raw columns: ['&Si-28', '&1.113E-05', '&9.517E-04', '&7.167E-04', '&2.139403E-04']
# Processed line: &Si-28 &1.113E-05 &9.517E-04 &7.167E-04 1.133361e-05
# Raw columns: ['&Si-29', '&1.548E-06', '&5.087E-05', '&3.768E-05', '&1.124776E-05']
# Processed line: &Si-29 &1.548E-06 &5.087E-05 &3.768E-05 1.548572e-06
# Raw columns: ['&Si-30', '&3.207E-06', '&3.707E-05', '&2.573E-05', '&7.680597E-06']
# Processed line: &Si-30 &3.207E-06 &3.707E-05 &2.573E-05 3.207285e-06
# Raw columns: ['&P-31', '&7.646E-07', '&9.733E-06', '&7.109E-06', '&2.122090E-06']
# Processed line: &P-31 &7.646E-07 &9.733E-06 &7.109E-06 7.646207e-07
# Raw columns: ['&S-32', '&-1.662E-06', '&6.656E-04', '&3.692E-04', '&1.102090E-04']
# Processed line: &S-32 &-1.662E-06 &6.656E-04 &3.692E-04 -1.588645e-06
# Raw columns: ['&S-33', '&2.603E-08', '&5.457E-06', '&2.996E-06', '&8.943284E-07']
# Processed line: &S-33 &2.603E-08 &5.457E-06 &2.996E-06 2.603488e-08
# Raw columns: ['&S-34', '&-1.295E-06', '&2.704E-04', '&1.727E-05', '&5.155224E-06']
# Processed line: &S-34 &-1.295E-06 &2.704E-04 &1.727E-05 -1.293606e-06
# Raw columns: ['&S-35', '&1.446E-06', '&1.446E-06', '&0.0', '&0.000000E+00']
# Processed line: &S-35 &1.446E-06 &1.446E-06 &0.0 1.446000e-06
# Raw columns: ['&Fe-54', '&-8.668E-07', '&1.008E-04', '&7.643E-05', '&2.281493E-05']
# Processed line: &Fe-54 &-8.668E-07 &1.008E-04 &7.643E-05 -8.645003e-07
# Raw columns: ['&Fe-55', '&3.566E-07', '&3.566E-07', '&0.0', '&0.000000E+00']
# Processed line: &Fe-55 &3.566E-07 &3.566E-07 &0.0 3.566000e-07
# Raw columns: ['&Fe-56', '&-7.993E-06', '&1.659E-03', '&1.245E-03', '&3.716418E-04']
# Processed line: &Fe-56 &-7.993E-06 &1.659E-03 &1.245E-03 -7.376446e-06
# Raw columns: ['&Fe-57', '&6.285E-07', '&4.133E-05', '&2.927E-05', '&8.737313E-06']
# Processed line: &Fe-57 &6.285E-07 &4.133E-05 &2.927E-05 6.288611e-07
# Raw columns: ['&Fe-58', '&1.859E-06', '&7.129E-06', '&3.960E-06', '&1.182090E-06']
# Processed line: &Fe-58 &1.859E-06 &7.129E-06 &3.960E-06 1.859008e-06
# Raw columns: ['&Fe-60', '&2.438E-06', '&2.438E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-60 &2.438E-06 &2.438E-06 &0.0 2.438000e-06
# Raw columns: ['&Co-59', '&9.190E-07', '&5.955E-06', '&3.701E-06', '&1.104776E-06']
# Processed line: &Co-59 &9.190E-07 &5.955E-06 &3.701E-06 9.190066e-07
# Raw columns: ['&Ni-58', '&-4.816E-07', '&7.180E-05', '&5.328E-05', '&1.590448E-05']
# Processed line: &Ni-58 &-4.816E-07 &7.180E-05 &5.328E-05 -4.804581e-07
# Raw columns: ['&Ni-60', '&1.162E-07', '&2.870E-05', '&2.131E-05', '&6.361194E-06']
# Processed line: &Ni-60 &1.162E-07 &2.870E-05 &2.131E-05 1.163826e-07
# Raw columns: ['&Ni-61', '&7.625E-06', '&8.884E-06', '&9.396E-07', '&2.804776E-07']
# Processed line: &Ni-61 &7.625E-06 &8.884E-06 &9.396E-07 7.625002e-06
# Raw columns: ['&Ni-62', '&-4.036E-06', '&2.605E-08', '&3.046E-06', '&9.092537E-07']
# Processed line: &Ni-62 &-4.036E-06 &2.605E-08 &3.046E-06 -4.036000e-06
# Raw columns: ['&Isotopes', '&NetYield', '&MassExp', '&X_i,solar', '&X_i,0', '&Yields']
# Skipping line due to ValueError: &Isotopes &NetYield &MassExp &X_i,solar &X_i,0 &Yields - could not convert string to float: 'NetYield'
# Raw columns: ['&H', '&-6.849E-01', '&4.344E+00', '&7.057E-01', '&2.106567E-01']
# Processed line: &H &-6.849E-01 &4.344E+00 &7.057E-01 2.301927e-01
# Raw columns: ['&He-3', '&1.579E-05', '&1.579E-05', '&3.461E-05', '&1.033134E-05']
# Processed line: &He-3 &1.579E-05 &1.579E-05 &3.461E-05 1.579016e-05
# Raw columns: ['&He-4', '&6.644E-01', '&2.380E+00', '&2.769E-01', '&8.265672E-02']
# Processed line: &He-4 &6.644E-01 &2.380E+00 &2.769E-01 8.611230e-01
# Raw columns: ['&Li-7', '&1.234E-07', '&1.379E-07', '&1.025E-08', '&3.059701E-09']
# Processed line: &Li-7 &1.234E-07 &1.379E-07 &1.025E-08 1.234000e-07
# Raw columns: ['&C-12', '&-2.674E-03', '&2.204E-03', '&3.011E-03', '&8.988060E-04']
# Processed line: &C-12 &-2.674E-03 &2.204E-03 &3.011E-03 -2.672019e-03
# Raw columns: ['&C-13', '&4.559E-04', '&5.115E-04', '&3.411E-05', '&1.018209E-05']
# Processed line: &C-13 &4.559E-04 &5.115E-04 &3.411E-05 4.559052e-04
# Raw columns: ['&N-14', '&2.434E-02', '&2.583E-02', '&8.482E-04', '&2.531940E-04']
# Processed line: &N-14 &2.434E-02 &2.583E-02 &8.482E-04 2.434654e-02
# Raw columns: ['&N-15', '&-2.177E-06', '&3.439E-06', '&2.059E-06', '&6.146269E-07']
# Processed line: &N-15 &-2.177E-06 &3.439E-06 &2.059E-06 -2.176998e-06
# Raw columns: ['&O-16', '&-2.138E-03', '&1.145E-02', '&7.377E-03', '&2.202090E-03']
# Processed line: &O-16 &-2.138E-03 &1.145E-02 &7.377E-03 -2.112786e-03
# Raw columns: ['&O-17', '&6.657E-05', '&7.182E-05', '&2.739E-06', '&8.176119E-07']
# Processed line: &O-17 &6.657E-05 &7.182E-05 &2.739E-06 6.657006e-05
# Raw columns: ['&O-18', '&-2.791E-05', '&1.347E-06', '&1.565E-05', '&4.671642E-06']
# Processed line: &O-18 &-2.791E-05 &1.347E-06 &1.565E-05 -2.790999e-05
# Raw columns: ['&F-19', '&-6.596E-07', '&9.658E-08', '&6.688E-07', '&1.996418E-07']
# Processed line: &F-19 &-6.596E-07 &9.658E-08 &6.688E-07 -6.596000e-07
# Raw columns: ['&Ne-20', '&3.595E-05', '&2.487E-03', '&2.261E-03', '&6.749254E-04']
# Processed line: &Ne-20 &3.595E-05 &2.487E-03 &2.261E-03 3.762854e-05
# Raw columns: ['&Ne-21', '&-5.787E-06', '&4.673E-07', '&5.693E-06', '&1.699403E-06']
# Processed line: &Ne-21 &-5.787E-06 &4.673E-07 &5.693E-06 -5.786999e-06
# Raw columns: ['&Ne-22', '&2.259E-04', '&4.227E-04', '&1.772E-04', '&5.289552E-05']
# Processed line: &Ne-22 &2.259E-04 &4.227E-04 &1.772E-04 2.259224e-04
# Raw columns: ['&Na-23', '&2.031E-05', '&7.422E-05', '&3.692E-05', '&1.102090E-05']
# Processed line: &Na-23 &2.031E-05 &7.422E-05 &3.692E-05 2.031082e-05
# Raw columns: ['&Mg-24', '&-6.446E-04', '&1.454E-04', '&5.398E-04', '&1.611343E-04']
# Processed line: &Mg-24 &-6.446E-04 &1.454E-04 &5.398E-04 -6.445766e-04
# Raw columns: ['&Mg-25', '&6.864E-04', '&7.906E-04', '&7.151E-05', '&2.134627E-05']
# Processed line: &Mg-25 &6.864E-04 &7.906E-04 &7.151E-05 6.864169e-04
# Raw columns: ['&Mg-26', '&1.322E-04', '&2.515E-04', '&8.158E-05', '&2.435224E-05']
# Processed line: &Mg-26 &1.322E-04 &2.515E-04 &8.158E-05 1.322061e-04
# Raw columns: ['&Al-26', '&1.248E-05', '&1.248E-05', '&0.0', '&0.000000E+00']
# Processed line: &Al-26 &1.248E-05 &1.248E-05 &0.0 1.248000e-05
# Raw columns: ['&Al-27', '&9.898E-06', '&9.724E-05', '&6.132E-05', '&1.830448E-05']
# Processed line: &Al-27 &9.898E-06 &9.724E-05 &6.132E-05 9.899780e-06
# Raw columns: ['&Si-28', '&9.476E-06', '&1.014E-03', '&7.167E-04', '&2.139403E-04']
# Processed line: &Si-28 &9.476E-06 &1.014E-03 &7.167E-04 9.692935e-06
# Raw columns: ['&Si-29', '&1.192E-06', '&5.386E-05', '&3.768E-05', '&1.124776E-05']
# Processed line: &Si-29 &1.192E-06 &5.386E-05 &3.768E-05 1.192606e-06
# Raw columns: ['&Si-30', '&2.772E-06', '&3.893E-05', '&2.573E-05', '&7.680597E-06']
# Processed line: &Si-30 &2.772E-06 &3.893E-05 &2.573E-05 2.772299e-06
# Raw columns: ['&P-31', '&7.261E-07', '&1.030E-05', '&7.109E-06', '&2.122090E-06']
# Processed line: &P-31 &7.261E-07 &1.030E-05 &7.109E-06 7.261219e-07
# Raw columns: ['&S-32', '&-1.398E-06', '&7.111E-04', '&3.692E-04', '&1.102090E-04']
# Processed line: &S-32 &-1.398E-06 &7.111E-04 &3.692E-04 -1.319630e-06
# Raw columns: ['&S-33', '&2.775E-08', '&5.827E-06', '&2.996E-06', '&8.943284E-07']
# Processed line: &S-33 &2.775E-08 &5.827E-06 &2.996E-06 2.775521e-08
# Raw columns: ['&S-34', '&-1.133E-06', '&2.890E-04', '&1.727E-05', '&5.155224E-06']
# Processed line: &S-34 &-1.133E-06 &2.890E-04 &1.727E-05 -1.131510e-06
# Raw columns: ['&S-35', '&1.265E-06', '&1.265E-06', '&0.0', '&0.000000E+00']
# Processed line: &S-35 &1.265E-06 &1.265E-06 &0.0 1.265000e-06
# Raw columns: ['&Fe-54', '&-8.551E-07', '&1.077E-04', '&7.643E-05', '&2.281493E-05']
# Processed line: &Fe-54 &-8.551E-07 &1.077E-04 &7.643E-05 -8.526428e-07
# Raw columns: ['&Fe-55', '&4.302E-07', '&4.302E-07', '&0.0', '&0.000000E+00']
# Processed line: &Fe-55 &4.302E-07 &4.302E-07 &0.0 4.302000e-07
# Raw columns: ['&Fe-56', '&-6.706E-06', '&1.774E-03', '&1.245E-03', '&3.716418E-04']
# Processed line: &Fe-56 &-6.706E-06 &1.774E-03 &1.245E-03 -6.046707e-06
# Raw columns: ['&Fe-57', '&7.443E-07', '&4.421E-05', '&2.927E-05', '&8.737313E-06']
# Processed line: &Fe-57 &7.443E-07 &4.421E-05 &2.927E-05 7.446863e-07
# Raw columns: ['&Fe-58', '&1.311E-06', '&6.939E-06', '&3.960E-06', '&1.182090E-06']
# Processed line: &Fe-58 &1.311E-06 &6.939E-06 &3.960E-06 1.311008e-06
# Raw columns: ['&Fe-60', '&2.021E-06', '&2.021E-06', '&0.0', '&0.000000E+00']
# Processed line: &Fe-60 &2.021E-06 &2.021E-06 &0.0 2.021000e-06
# Raw columns: ['&Co-59', '&6.437E-07', '&6.021E-06', '&3.701E-06', '&1.104776E-06']
# Processed line: &Co-59 &6.437E-07 &6.021E-06 &3.701E-06 6.437067e-07
# Raw columns: ['&Ni-58', '&-4.479E-07', '&7.673E-05', '&5.328E-05', '&1.590448E-05']
# Processed line: &Ni-58 &-4.479E-07 &7.673E-05 &5.328E-05 -4.466796e-07
# Raw columns: ['&Ni-60', '&4.975E-08', '&3.057E-05', '&2.131E-05', '&6.361194E-06']
# Processed line: &Ni-60 &4.975E-08 &3.057E-05 &2.131E-05 4.994446e-08
# Raw columns: ['&Ni-61', '&7.537E-06', '&8.880E-06', '&9.396E-07', '&2.804776E-07']
# Processed line: &Ni-61 &7.537E-06 &8.880E-06 &9.396E-07 7.537002e-06
# Raw columns: ['&Ni-62', '&-4.310E-06', '&2.704E-08', '&3.046E-06', '&9.092537E-07']
# Processed line: &Ni-62 &-4.310E-06 &2.704E-08 &3.046E-06 -4.310000e-06

# %%
import re

# File paths
input_file = "super_agb_doherty13_x_i,0.txt"
output_file = "super_agb_doherty13_total_yields.txt"

# Regular expression to match rows starting with '&'
row_pattern = re.compile(r"^&")

# Read the input file
with open(input_file, 'r') as file:
    lines = file.readlines()

# Process the file
updated_lines = []
for line in lines:
    if row_pattern.match(line):
        # Split the line into columns
        columns = line.split()
        # Debug: Print the raw columns for inspection
        # Ensure the row has enough columns and valid numeric data
        try:
            # Extract relevant values, handling the '&' symbol
            p_i = float(columns[1].lstrip('&'))  # Net Yield
            M_ej = float(columns[2].lstrip('&'))  # MassExp
            X_i_0 = float(columns[-1].lstrip('&'))  # X_i,0 (last column)
            print(columns[2])  # Debug print for X_i,0
            # Calculate Total yield
            total_yield = p_i + M_ej * X_i_0

            # Update the Total yield column (8th column, index 7)
            columns[4] = f"{total_yield:.6e}"
        except ValueError as e:
            continue

        # Reconstruct the line
        line = " ".join(columns) + "\n"

    # Append the processed or unprocessed line
    updated_lines.append(line)

# Write the updated lines back to the file
with open(output_file, 'w') as file:
    file.writelines(updated_lines)

print("Total yield column updated successfully.")
# Out:
# &3.770E+00
# &1.589E-05
# &2.128E+00
# &5.857E-08
# &6.763E-03
# &7.983E-04
# &4.301E-02
# &1.195E-06
# &4.764E-02
# &1.245E-04
# &2.485E-06
# &2.033E-06
# &1.089E-02
# &2.269E-06
# &1.450E-03
# &4.395E-04
# &3.479E-03
# &5.186E-04
# &7.372E-04
# &3.064E-06
# &4.071E-04
# &4.488E-03
# &2.375E-04
# &1.668E-04
# &4.354E-05
# &3.169E-03
# &2.604E-05
# &1.287E-03
# &5.194E-06
# &4.799E-04
# &1.175E-06
# &7.897E-03
# &2.003E-04
# &4.089E-05
# &2.817E-06
# &2.865E-05
# &3.414E-04
# &1.370E-04
# &3.176E-05
# &1.292E-07
# &4.017E+00
# &1.828E-05
# &2.329E+00
# &8.094E-08
# &7.379E-03
# &9.007E-04
# &4.533E-02
# &1.352E-06
# &5.034E-02
# &1.511E-04
# &2.614E-06
# &1.857E-06
# &1.172E-02
# &2.986E-06
# &1.349E-03
# &4.873E-04
# &3.721E-03
# &5.914E-04
# &8.368E-04
# &4.072E-06
# &4.323E-04
# &4.830E-03
# &2.560E-04
# &1.803E-04
# &4.711E-05
# &3.409E-03
# &2.797E-05
# &1.385E-03
# &5.681E-06
# &5.164E-04
# &1.354E-06
# &8.496E-03
# &2.140E-04
# &4.244E-05
# &4.423E-06
# &3.103E-05
# &3.674E-04
# &1.473E-04
# &3.551E-05
# &1.357E-07
# &4.256E+00
# &1.879E-05
# &2.518E+00
# &1.122E-07
# &7.470E-03
# &1.071E-03
# &4.985E-02
# &1.778E-06
# &5.270E-02
# &1.999E-04
# &2.900E-06
# &1.408E-06
# &1.252E-02
# &3.734E-06
# &1.546E-03
# &5.236E-04
# &3.821E-03
# &8.317E-04
# &1.019E-03
# &6.165E-06
# &4.572E-04
# &5.160E-03
# &2.752E-04
# &1.960E-04
# &5.110E-05
# &3.637E-03
# &2.983E-05
# &1.477E-03
# &7.077E-06
# &5.510E-04
# &1.564E-06
# &9.063E-03
# &2.269E-04
# &4.407E-05
# &9.088E-06
# &3.391E-05
# &3.922E-04
# &1.573E-04
# &4.169E-05
# &1.437E-07
# &4.494E+00
# &2.176E-05
# &2.689E+00
# &1.679E-07
# &7.784E-03
# &1.248E-03
# &5.383E-02
# &2.745E-06
# &5.518E-02
# &2.701E-04
# &4.473E-06
# &1.038E-06
# &1.330E-02
# &4.213E-06
# &1.516E-03
# &5.450E-04
# &3.555E-03
# &1.447E-03
# &1.218E-03
# &9.460E-06
# &4.844E-04
# &5.472E-03
# &2.933E-04
# &2.114E-04
# &5.509E-05
# &3.856E-03
# &3.162E-05
# &1.566E-03
# &7.992E-06
# &5.844E-04
# &1.714E-06
# &9.609E-03
# &2.392E-04
# &4.309E-05
# &1.419E-05
# &3.554E-05
# &4.159E-04
# &1.664E-04
# &4.760E-05
# &1.489E-07
# &4.732E+00
# &2.800E-05
# &2.863E+00
# &2.760E-07
# &7.375E-03
# &1.490E-03
# &6.232E-02
# &6.115E-06
# &5.948E-02
# &3.313E-04
# &9.548E-06
# &1.003E-06
# &1.409E-02
# &4.757E-06
# &2.056E-03
# &5.727E-04
# &3.240E-03
# &2.054E-03
# &1.252E-03
# &1.205E-05
# &5.123E-04
# &5.787E-03
# &3.091E-04
# &2.224E-04
# &5.810E-05
# &4.083E-03
# &3.346E-05
# &1.659E-03
# &7.473E-06
# &6.187E-04
# &2.091E-06
# &1.018E-02
# &2.534E-04
# &4.222E-05
# &1.365E-05
# &3.614E-05
# &4.405E-04
# &1.757E-04
# &4.853E-05
# &1.559E-07
# &3.577E+00
# &4.836E-06
# &1.892E+00
# &2.999E-10
# &5.664E-03
# &6.495E-04
# &4.330E-02
# &1.144E-06
# &1.479E-02
# &4.335E-05
# &1.186E-06
# &8.174E-07
# &4.017E-03
# &9.921E-07
# &1.232E-03
# &1.498E-04
# &1.042E-03
# &5.349E-04
# &5.323E-04
# &1.327E-05
# &1.585E-04
# &1.673E-03
# &9.212E-05
# &6.906E-05
# &1.745E-05
# &1.161E-03
# &9.655E-06
# &4.695E-04
# &6.275E-06
# &1.744E-04
# &4.420E-07
# &2.878E-03
# &7.526E-05
# &2.597E-05
# &6.504E-06
# &1.483E-05
# &1.241E-04
# &5.158E-05
# &2.065E-05
# &5.531E-08
# &3.870E+00
# &4.827E-06
# &2.062E+00
# &5.966E-10
# &4.822E-03
# &5.573E-04
# &3.290E-02
# &1.066E-06
# &1.618E-02
# &5.827E-05
# &1.328E-06
# &5.011E-07
# &4.345E-03
# &8.442E-07
# &7.740E-04
# &1.537E-04
# &9.486E-04
# &6.933E-04
# &4.162E-04
# &1.510E-05
# &1.642E-04
# &1.799E-03
# &9.715E-05
# &7.037E-05
# &1.810E-05
# &1.259E-03
# &1.037E-05
# &5.104E-04
# &3.979E-06
# &1.900E-04
# &5.263E-07
# &3.131E-03
# &7.976E-05
# &2.009E-05
# &4.285E-06
# &1.327E-05
# &1.352E-04
# &5.498E-05
# &1.699E-05
# &5.893E-08
# &4.144E+00
# &5.558E-06
# &2.230E+00
# &7.687E-09
# &4.673E-03
# &6.072E-04
# &2.870E-02
# &1.147E-06
# &1.840E-02
# &8.110E-05
# &1.475E-06
# &3.019E-07
# &4.668E-03
# &9.010E-07
# &6.378E-04
# &1.700E-04
# &9.045E-04
# &8.544E-04
# &4.345E-04
# &1.348E-05
# &1.741E-04
# &1.924E-03
# &1.033E-04
# &7.453E-05
# &1.941E-05
# &1.352E-03
# &1.110E-05
# &5.490E-04
# &3.180E-06
# &2.046E-04
# &6.113E-07
# &3.369E-03
# &8.442E-05
# &1.685E-05
# &4.382E-06
# &1.280E-05
# &1.457E-04
# &5.860E-05
# &1.743E-05
# &6.299E-08
# &4.405E+00
# &1.119E-05
# &2.384E+00
# &6.147E-08
# &4.585E-03
# &6.259E-04
# &2.836E-02
# &1.770E-06
# &1.992E-02
# &1.093E-04
# &1.709E-06
# &2.370E-07
# &4.993E-03
# &1.047E-06
# &6.339E-04
# &1.640E-04
# &5.953E-04
# &1.294E-03
# &4.860E-04
# &1.789E-05
# &1.862E-04
# &2.047E-03
# &1.098E-04
# &7.961E-05
# &2.079E-05
# &1.440E-03
# &1.180E-05
# &5.848E-04
# &3.079E-06
# &2.181E-04
# &6.846E-07
# &3.589E-03
# &8.933E-05
# &1.586E-05
# &5.340E-06
# &1.309E-05
# &1.553E-04
# &6.216E-05
# &1.852E-05
# &6.690E-08
# &4.650E+00
# &1.992E-05
# &2.543E+00
# &1.659E-07
# &4.826E-03
# &8.522E-04
# &3.576E-02
# &3.522E-06
# &2.290E-02
# &1.358E-04
# &3.377E-06
# &2.696E-07
# &5.313E-03
# &1.481E-06
# &8.782E-04
# &1.773E-04
# &5.363E-04
# &1.491E-03
# &5.571E-04
# &1.504E-05
# &1.979E-04
# &2.171E-03
# &1.164E-04
# &8.489E-05
# &2.228E-05
# &1.527E-03
# &1.253E-05
# &6.205E-04
# &3.162E-06
# &2.314E-04
# &8.289E-07
# &3.808E-03
# &9.473E-05
# &1.528E-05
# &6.021E-06
# &1.331E-05
# &1.648E-04
# &6.572E-05
# &2.027E-05
# &7.049E-08
# &3.531E+00
# &3.871E-06
# &1.915E+00
# &1.340E-10
# &4.291E-03
# &5.299E-04
# &3.020E-02
# &9.679E-07
# &5.857E-03
# &2.219E-05
# &4.817E-07
# &2.648E-07
# &2.008E-03
# &5.346E-07
# &5.090E-04
# &5.608E-05
# &1.639E-04
# &6.156E-04
# &3.179E-04
# &2.835E-05
# &8.416E-05
# &8.297E-04
# &4.567E-05
# &3.467E-05
# &5.750E-04
# &4.755E-06
# &2.329E-04
# &2.712E-06
# &8.666E-05
# &2.639E-07
# &1.428E-03
# &3.647E-05
# &1.004E-05
# &3.697E-06
# &6.532E-06
# &6.169E-05
# &2.530E-05
# &1.076E-05
# &2.353E-08
# &3.824E+00
# &3.671E-06
# &2.073E+00
# &5.333E-10
# &3.389E-03
# &4.014E-04
# &2.116E-02
# &8.829E-07
# &6.978E-03
# &3.398E-05
# &5.176E-07
# &1.463E-07
# &2.172E-03
# &3.841E-07
# &3.472E-04
# &5.476E-05
# &9.642E-05
# &7.140E-04
# &2.325E-04
# &2.493E-05
# &8.752E-05
# &8.906E-04
# &4.788E-05
# &3.492E-05
# &9.105E-06
# &6.227E-04
# &5.114E-06
# &2.528E-04
# &1.656E-06
# &9.419E-05
# &3.170E-07
# &1.551E-03
# &3.894E-05
# &7.908E-06
# &2.386E-06
# &5.978E-06
# &6.707E-05
# &2.701E-05
# &8.615E-06
# &2.441E-08
# &4.085E+00
# &6.000E-06
# &2.218E+00
# &2.607E-08
# &3.404E-03
# &4.279E-04
# &1.918E-02
# &1.319E-06
# &8.223E-03
# &4.885E-05
# &5.752E-07
# &7.989E-08
# &2.334E-03
# &4.180E-07
# &3.285E-04
# &5.394E-05
# &8.672E-05
# &7.862E-04
# &2.499E-04
# &1.995E-05
# &9.320E-05
# &9.517E-04
# &5.087E-05
# &3.707E-05
# &9.733E-06
# &6.656E-04
# &5.457E-06
# &2.704E-04
# &1.446E-06
# &1.008E-04
# &3.566E-07
# &1.659E-03
# &4.133E-05
# &7.129E-06
# &2.438E-06
# &5.955E-06
# &7.180E-05
# &2.870E-05
# &8.884E-06
# &2.605E-08
# &4.344E+00
# &1.579E-05
# &2.380E+00
# &1.379E-07
# &2.204E-03
# &5.115E-04
# &2.583E-02
# &3.439E-06
# &1.145E-02
# &7.182E-05
# &1.347E-06
# &9.658E-08
# &2.487E-03
# &4.673E-07
# &4.227E-04
# &7.422E-05
# &1.454E-04
# &7.906E-04
# &2.515E-04
# &1.248E-05
# &9.724E-05
# &1.014E-03
# &5.386E-05
# &3.893E-05
# &1.030E-05
# &7.111E-04
# &5.827E-06
# &2.890E-04
# &1.265E-06
# &1.077E-04
# &4.302E-07
# &1.774E-03
# &4.421E-05
# &6.939E-06
# &2.021E-06
# &6.021E-06
# &7.673E-05
# &3.057E-05
# &8.880E-06
# &2.704E-08
# Total yield column updated successfully.
